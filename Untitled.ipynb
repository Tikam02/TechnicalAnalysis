# %%
# !pip install quanttrader
# Out:
# Collecting quanttrader
#   Using cached quanttrader-0.5.5-py3-none-any.whl (101 kB)
# Requirement already satisfied: matplotlib>=3.0.3 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from quanttrader) (3.8.2)
# Requirement already satisfied: numpy>=1.18.0 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from quanttrader) (1.26.2)
# Requirement already satisfied: pandas>=1.0.5 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from quanttrader) (2.1.4)
# Requirement already satisfied: psutil>=5.7.0 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from quanttrader) (5.9.7)
# Requirement already satisfied: pytz>=2018.9 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from quanttrader) (2023.3.post1)
# Requirement already satisfied: scipy>=1.4.1 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from quanttrader) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.22.1 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from quanttrader) (1.4.0)
# Requirement already satisfied: seaborn>=0.10.1 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from quanttrader) (0.13.1)
# Collecting pytest>=3.6.4 (from quanttrader)
#   Using cached pytest-7.4.4-py3-none-any.whl.metadata (7.9 kB)
# Collecting PyQt5>=5.10.1 (from quanttrader)
#   Using cached PyQt5-5.15.10-cp37-abi3-manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting QDarkStyle>=2.8 (from quanttrader)
#   Using cached QDarkStyle-3.2.3-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: PyYAML>=5.3.1 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from quanttrader) (6.0.1)
# Collecting ibapi>=9.76.1 (from quanttrader)
#   Using cached ibapi-9.81.1.post1.tar.gz (61 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gym>=0.21.0 (from quanttrader)
#   Using cached gym-0.26.2.tar.gz (721 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting cloudpickle>=1.2.0 (from gym>=0.21.0->quanttrader)
#   Using cached cloudpickle-3.0.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting gym-notices>=0.0.4 (from gym>=0.21.0->quanttrader)
#   Using cached gym_notices-0.0.8-py3-none-any.whl (3.0 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from matplotlib>=3.0.3->quanttrader) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from matplotlib>=3.0.3->quanttrader) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from matplotlib>=3.0.3->quanttrader) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from matplotlib>=3.0.3->quanttrader) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from matplotlib>=3.0.3->quanttrader) (23.2)
# Requirement already satisfied: pillow>=8 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from matplotlib>=3.0.3->quanttrader) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from matplotlib>=3.0.3->quanttrader) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from matplotlib>=3.0.3->quanttrader) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from pandas>=1.0.5->quanttrader) (2023.3)
# Collecting PyQt5-sip<13,>=12.13 (from PyQt5>=5.10.1->quanttrader)
#   Using cached PyQt5_sip-12.13.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (504 bytes)
# Collecting PyQt5-Qt5>=5.15.2 (from PyQt5>=5.10.1->quanttrader)
#   Downloading PyQt5_Qt5-5.15.2-py3-none-manylinux2014_x86_64.whl (59.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 MB 1.2 MB/s eta 0:00:00m eta 0:00:010:00:02
# Collecting iniconfig (from pytest>=3.6.4->quanttrader)
#   Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Collecting pluggy<2.0,>=0.12 (from pytest>=3.6.4->quanttrader)
#   Downloading pluggy-1.3.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from pytest>=3.6.4->quanttrader) (1.2.0)
# Requirement already satisfied: tomli>=1.0.0 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from pytest>=3.6.4->quanttrader) (2.0.1)
# Collecting qtpy>=2 (from QDarkStyle>=2.8->quanttrader)
#   Downloading QtPy-2.4.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: joblib>=1.2.0 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from scikit-learn>=0.22.1->quanttrader) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from scikit-learn>=0.22.1->quanttrader) (3.2.0)
# Requirement already satisfied: six>=1.5 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.3->quanttrader) (1.16.0)
# Downloading PyQt5-5.15.10-cp37-abi3-manylinux_2_17_x86_64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 904.0 kB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading pytest-7.4.4-py3-none-any.whl (325 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.3/325.3 kB 1.0 MB/s eta 0:00:000:00:01m eta 0:00:01
# Downloading QDarkStyle-3.2.3-py2.py3-none-any.whl (871 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.8/871.8 kB 1.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Downloading pluggy-1.3.0-py3-none-any.whl (18 kB)
# Downloading PyQt5_sip-12.13.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.whl (338 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 338.1/338.1 kB 1.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading QtPy-2.4.1-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 593.3 kB/s eta 0:00:006m0:00:01m eta 0:00:01
# Building wheels for collected packages: gym, ibapi
#   Building wheel for gym (pyproject.toml) ... done
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827619 sha256=a86b01f47f791f035474c53695825050bb75d4b3bc1f2142a97478e946eee9a8
#   Stored in directory: /home/tikam/.cache/pip/wheels/b9/22/6d/3e7b32d98451b4cd9d12417052affbeeeea012955d437da1da
#   Building wheel for ibapi (setup.py) ... done
#   Created wheel for ibapi: filename=ibapi-9.81.1.post1-py3-none-any.whl size=67941 sha256=410014b710c7634d4a3ee6073097f9607b93cfc61c7708e5d5815e0213bea30e
#   Stored in directory: /home/tikam/.cache/pip/wheels/e4/77/34/78c9688c4423261f0f80b86e94655e63b2df440a268d56e39f
# Successfully built gym ibapi
# Installing collected packages: PyQt5-Qt5, gym-notices, qtpy, PyQt5-sip, pluggy, iniconfig, ibapi, cloudpickle, QDarkStyle, pytest, PyQt5, gym, quanttrader
# Successfully installed PyQt5-5.15.10 PyQt5-Qt5-5.15.2 PyQt5-sip-12.13.0 QDarkStyle-3.2.3 cloudpickle-3.0.0 gym-0.26.2 gym-notices-0.0.8 ibapi-9.81.1.post1 iniconfig-2.0.0 pluggy-1.3.0 pytest-7.4.4 qtpy-2.4.1 quanttrader-0.5.5

# %%
# !pip install empyrical
# Out:
# Collecting empyrical
#   Downloading empyrical-0.5.5.tar.gz (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 239.8 kB/s eta 0:00:001m514.1 kB/s eta 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.9.2 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from empyrical) (1.26.2)
# Requirement already satisfied: pandas>=0.16.1 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from empyrical) (2.1.4)
# Requirement already satisfied: scipy>=0.15.1 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from empyrical) (1.11.4)
# Requirement already satisfied: pandas-datareader>=0.2 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from empyrical) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from pandas>=0.16.1->empyrical) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from pandas>=0.16.1->empyrical) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from pandas>=0.16.1->empyrical) (2023.3)
# Requirement already satisfied: lxml in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from pandas-datareader>=0.2->empyrical) (5.1.0)
# Requirement already satisfied: requests>=2.19.0 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from pandas-datareader>=0.2->empyrical) (2.31.0)
# Requirement already satisfied: six>=1.5 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=0.16.1->empyrical) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from requests>=2.19.0->pandas-datareader>=0.2->empyrical) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from requests>=2.19.0->pandas-datareader>=0.2->empyrical) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from requests>=2.19.0->pandas-datareader>=0.2->empyrical) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from requests>=2.19.0->pandas-datareader>=0.2->empyrical) (2023.11.17)
# Building wheels for collected packages: empyrical
#   Building wheel for empyrical (setup.py) ... done
#   Created wheel for empyrical: filename=empyrical-0.5.5-py3-none-any.whl size=39754 sha256=e9d6905b14db7f63b1b96dcb74099522dc54650879b8e0331871fe5979bf32f0
#   Stored in directory: /home/tikam/.cache/pip/wheels/0e/2e/f2/d6d2d9a1eb8fbbd9949bb5d4c00f753e3b74e5bd7ed10b1d36
# Successfully built empyrical
# Installing collected packages: empyrical
# Successfully installed empyrical-0.5.5

# %%
# !pip install pyfolio
# Out:
# Collecting pyfolio
#   Downloading pyfolio-0.9.2.tar.gz (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 406.8 kB/s eta 0:00:00 kB/s eta 0:00:01:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ipython>=3.2.3 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from pyfolio) (8.19.0)
# Requirement already satisfied: matplotlib>=1.4.0 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from pyfolio) (3.8.2)
# Requirement already satisfied: numpy>=1.11.1 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from pyfolio) (1.26.2)
# Requirement already satisfied: pandas>=0.18.1 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from pyfolio) (2.1.4)
# Requirement already satisfied: pytz>=2014.10 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from pyfolio) (2023.3.post1)
# Requirement already satisfied: scipy>=0.14.0 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from pyfolio) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.16.1 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from pyfolio) (1.4.0)
# Requirement already satisfied: seaborn>=0.7.1 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from pyfolio) (0.13.1)
# Requirement already satisfied: empyrical>=0.5.0 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from pyfolio) (0.5.5)
# Requirement already satisfied: pandas-datareader>=0.2 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from empyrical>=0.5.0->pyfolio) (0.10.0)
# Requirement already satisfied: decorator in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio) (2.17.2)
# Requirement already satisfied: stack-data in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio) (0.6.3)
# Requirement already satisfied: traitlets>=5 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio) (5.14.0)
# Requirement already satisfied: exceptiongroup in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio) (4.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio) (23.2)
# Requirement already satisfied: pillow>=8 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from pandas>=0.18.1->pyfolio) (2023.3)
# Requirement already satisfied: joblib>=1.2.0 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from scikit-learn>=0.16.1->pyfolio) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from scikit-learn>=0.16.1->pyfolio) (3.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio) (0.8.3)
# Requirement already satisfied: lxml in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from pandas-datareader>=0.2->empyrical>=0.5.0->pyfolio) (5.1.0)
# Requirement already satisfied: requests>=2.19.0 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from pandas-datareader>=0.2->empyrical>=0.5.0->pyfolio) (2.31.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from pexpect>4.3->ipython>=3.2.3->pyfolio) (0.7.0)
# Requirement already satisfied: wcwidth in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=3.2.3->pyfolio) (0.2.12)
# Requirement already satisfied: six>=1.5 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->pyfolio) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from stack-data->ipython>=3.2.3->pyfolio) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from stack-data->ipython>=3.2.3->pyfolio) (2.4.1)
# Requirement already satisfied: pure-eval in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from stack-data->ipython>=3.2.3->pyfolio) (0.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from requests>=2.19.0->pandas-datareader>=0.2->empyrical>=0.5.0->pyfolio) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from requests>=2.19.0->pandas-datareader>=0.2->empyrical>=0.5.0->pyfolio) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from requests>=2.19.0->pandas-datareader>=0.2->empyrical>=0.5.0->pyfolio) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/tikam/stock-market/env3/lib/python3.10/site-packages (from requests>=2.19.0->pandas-datareader>=0.2->empyrical>=0.5.0->pyfolio) (2023.11.17)
# Building wheels for collected packages: pyfolio
#   Building wheel for pyfolio (setup.py) ... done
#   Created wheel for pyfolio: filename=pyfolio-0.9.2-py3-none-any.whl size=88650 sha256=645521cd11a8425a98ff1ba51434fbb0d20e3bea5f08c79faed5282f94588eb8
#   Stored in directory: /home/tikam/.cache/pip/wheels/71/38/bc/e53700cfd8b0ad6b539d2fbaaf060ed8a299e7622a5b86ef42
# Successfully built pyfolio
# Installing collected packages: pyfolio
# Successfully installed pyfolio-0.9.2

# %%
# !pip install pickle5
# Out:
# Collecting pickle5
#   Downloading pickle5-0.0.11.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.1/132.1 kB 459.7 kB/s eta 0:00:00 kB/s eta 0:00:01:01
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pickle5
#   Building wheel for pickle5 (setup.py) ... done
#   Created wheel for pickle5: filename=pickle5-0.0.11-cp310-cp310-linux_x86_64.whl size=255314 sha256=e0e06daa01470744592e47186cb61ce3c9ca19709f0ba8926d4c996c2f07141e
#   Stored in directory: /home/tikam/.cache/pip/wheels/7d/14/ef/4aab19d27fa8e58772be5c71c16add0426acf9e1f64353235c
# Successfully built pickle5
# Installing collected packages: pickle5
# Successfully installed pickle5-0.0.11

# %%
'''
golden cross buy; dead cross sell
'''
import os
import numpy as np
import pandas as pd
import pytz
from datetime import datetime, timezone
import multiprocessing
import quanttrader as qt
import matplotlib.pyplot as plt
import empyrical as ep
import pyfolio as pf
import pickle5 as pickle
# set browser full width
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))


class MADoubleCross(qt.StrategyBase):
    def __init__(self,
            short_window=50, long_window=200
    ):
        super(MADoubleCross, self).__init__()
        self.short_window = short_window
        self.long_window = long_window
        self.current_time = None
        self.current_position = 0

    def on_tick(self, tick_event):
        self.current_time = tick_event.timestamp
        # print('Processing {}'.format(self.current_time))
        symbol = self.symbols[0]

        df_hist = self._data_board.get_hist_price(symbol, tick_event.timestamp)
        current_price = df_hist.iloc[-1].Close

        # wait for enough bars
        if df_hist.shape[0] < self.long_window:
            return

        # Calculate the simple moving averages
        short_sma = np.mean(df_hist['Close'][-self.short_window:])
        long_sma = np.mean(df_hist['Close'][-self.long_window:])
        # Trading signals based on moving average cross
        if short_sma > long_sma and self.current_position <= 0:
            target_size = int((self._position_manager.cash + self.current_position * df_hist['Close'].iloc[-1])/df_hist['Close'].iloc[-1])       # buy to notional
            self.adjust_position(symbol, size_from=self.current_position, size_to=target_size, timestamp=self.current_time)
            print("Long: %s, short_sma %s, long_sma %s, price %s, trade %s, new position %s" % (self.current_time, str(short_sma), str(long_sma), str(current_price), str(target_size-self.current_position), str(target_size)))
            self.current_position = target_size
        elif short_sma < long_sma and self.current_position >= 0:
            target_size = int((self._position_manager.cash + self.current_position * df_hist['Close'].iloc[-1])/df_hist['Close'].iloc[-1])*(-1)    # sell to notional
            self.adjust_position(symbol, size_from=self.current_position, size_to=target_size, timestamp=self.current_time)
            print("Short: %s, short_sma %s, long_sma %s, price %s, trade %s, new position %s" % (self.current_time, str(short_sma), str(long_sma), str(current_price), str(target_size-self.current_position), str(target_size)))
            self.current_position = target_size


def parameter_search(engine, tag, target_name, return_dict):
    """
    This function should be the same for all strategies.
    The only reason not included in quanttrader is because of its dependency on pyfolio (to get perf_stats)
    """
    ds_equity, _, _ = engine.run()
    try:
        strat_ret = ds_equity.pct_change().dropna()
        perf_stats_strat = pf.timeseries.perf_stats(strat_ret)
        target_value = perf_stats_strat.loc[target_name]  # first table in tuple
    except KeyError:
        target_value = 0
    return_dict[tag] = target_value


if __name__ == '__main__':
    do_optimize = False
    run_in_jupyter = False
    is_intraday = True
    symbol = 'SPX'
    benchmark = 'SPX'
    init_capital = 100_000.0

    if not is_intraday:
        test_start_date = datetime(2010, 1, 1, 8, 30, 0, 0, pytz.timezone('America/New_York'))
        test_end_date = datetime(2019, 12, 31, 6, 0, 0, 0, pytz.timezone('America/New_York'))
        datapath = os.path.join('./datasets/', f'{symbol}.csv')
        data = qt.util.read_ohlcv_csv(datapath)
    else:
        # it seems initialize timezone doesn't work
        eastern = pytz.timezone('US/Eastern')
        test_start_date = eastern.localize(datetime(2020, 8, 10, 9, 30, 0))
        test_end_date = eastern.localize(datetime(2020, 8, 10, 10, 0, 0))
        dict_hist_data = {}
        if os.path.isfile('./datasets/tick/20200810.pkl'):
            with open('./datasets/tick/20200810.pkl', 'rb') as f:
                dict_hist_data = pickle.load(f)
        data = dict_hist_data['ESU0 FUT GLOBEX']
        data.index = data.index.tz_localize('America/New_York')  # US/Eastern, UTC

    if do_optimize:          # parallel parameter search
        params_list = []
        for sw in [10, 20, 30, 50, 100, 200]:
            for lw in [10, 20, 30, 50, 100, 200]:
                if lw <= sw:
                    continue
                params_list.append({'short_window': sw, 'long_window': lw})
        target_name = 'Sharpe ratio'
        manager = multiprocessing.Manager()
        return_dict = manager.dict()
        jobs = []
        for params in params_list:
            strategy = MADoubleCross()
            strategy.set_capital(init_capital)
            strategy.set_symbols([symbol])
            backtest_engine = qt.BacktestEngine(test_start_date, test_end_date)
            backtest_engine.set_capital(init_capital)  # capital or portfolio >= capital for one strategy
            backtest_engine.add_data(symbol, data)
            strategy.set_params({'short_window': params['short_window'], 'long_window': params['long_window']})
            backtest_engine.set_strategy(strategy)
            tag = (params['short_window'], params['long_window'])
            p = multiprocessing.Process(target=parameter_search, args=(backtest_engine, tag, target_name, return_dict))
            jobs.append(p)
            p.start()

        for proc in jobs:
            proc.join()
        for k,v in return_dict.items():
            print(k, v)
    else:
        strategy = MADoubleCross()
        strategy.set_capital(init_capital)
        strategy.set_symbols([symbol])
        strategy.set_params({'short_window':20, 'long_window':200})

        # Create a Data Feed
        backtest_engine = qt.BacktestEngine(test_start_date, test_end_date)
        backtest_engine.set_capital(init_capital)  # capital or portfolio >= capital for one strategy
        backtest_engine.add_data(symbol, data)
        backtest_engine.set_strategy(strategy)
        ds_equity, df_positions, df_trades = backtest_engine.run()
        # save to excel
        qt.util.save_one_run_results('./output', ds_equity, df_positions, df_trades)

        # ------------------------- Evaluation and Plotting -------------------------------------- #
        strat_ret = ds_equity.pct_change().dropna()
        strat_ret.name = 'strat'
        if not is_intraday:
            bm = qt.util.read_ohlcv_csv(os.path.join('../data/', f'{benchmark}.csv'))
        else:
            bm = data      # buy and hold
        bm_ret = bm['Close'].pct_change().dropna()
        bm_ret.index = pd.to_datetime(bm_ret.index)
        bm_ret = bm_ret[strat_ret.index]
        bm_ret.name = 'benchmark'

        perf_stats_strat = pf.timeseries.perf_stats(strat_ret)
        perf_stats_all = perf_stats_strat
        perf_stats_bm = pf.timeseries.perf_stats(bm_ret)
        perf_stats_all = pd.concat([perf_stats_strat, perf_stats_bm], axis=1)
        perf_stats_all.columns = ['Strategy', 'Benchmark']

        drawdown_table = pf.timeseries.gen_drawdown_table(strat_ret, 5)
        monthly_ret_table = ep.aggregate_returns(strat_ret, 'monthly')
        monthly_ret_table = monthly_ret_table.unstack().round(3)
        ann_ret_df = pd.DataFrame(ep.aggregate_returns(strat_ret, 'yearly'))
        ann_ret_df = ann_ret_df.unstack().round(3)

        print('-------------- PERFORMANCE ----------------')
        print(perf_stats_all)
        print('-------------- DRAWDOWN ----------------')
        print(drawdown_table)
        print('-------------- MONTHLY RETURN ----------------')
        print(monthly_ret_table)
        print('-------------- ANNUAL RETURN ----------------')
        print(ann_ret_df)

        if run_in_jupyter:
            pf.create_full_tear_sheet(
                strat_ret,
                benchmark_rets=bm_ret,
                positions=df_positions,
                transactions=df_trades,
                round_trips=False)
            plt.show()
        else:
            pf.plotting.show_perf_stats(
                strat_ret, bm_ret,
                positions=df_positions,
                transactions=df_trades)
            pf.plotting.show_worst_drawdown_periods(strat_ret)

            pf.plot_perf_stats(strat_ret, bm_ret)
            plt.show()
            pf.plotting.plot_returns(strat_ret)
            plt.show()
            f1 = plt.figure(1)
            pf.plot_rolling_returns(strat_ret, factor_returns=bm_ret)
            f1.show()
            f2 = plt.figure(2)
            pf.plot_rolling_volatility(strat_ret, factor_returns=bm_ret)
            f2.show()
            f3 = plt.figure(3)
            pf.plot_rolling_sharpe(strat_ret)
            f3.show()
            f4 = plt.figure(4)
            pf.plot_drawdown_periods(strat_ret)
            f4.show()
            f5 = plt.figure(5)
            pf.plot_monthly_returns_heatmap(strat_ret)
            f5.show()
            f6 = plt.figure(6)
            pf.plot_annual_returns(strat_ret)
            f6.show()
            f7 = plt.figure(7)
            pf.plot_monthly_returns_dist(strat_ret)
            plt.show()
            f8 = plt.figure(8)
            pf.create_interesting_times_tear_sheet(strat_ret, benchmark_rets=bm_ret)
            plt.show()
            f9 = plt.figure(9)
            pf.create_position_tear_sheet(strat_ret, df_positions)
            # plt.show()
            f10 = plt.figure(10)
            pf.create_txn_tear_sheet(strat_ret, df_positions, df_trades)
            # plt.show()
            f11 = plt.figure(11)
            pf.create_round_trip_tear_sheet(strat_ret, df_positions, df_trades)
            plt.show()
# Out:
# /tmp/ipykernel_11961/1007457721.py:16: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 95
#      93         with open('./datasets/tick/20200810.pkl', 'rb') as f:
#      94             dict_hist_data = pickle.load(f)
# ---> 95     data = dict_hist_data['ESU0 FUT GLOBEX']
#      96     data.index = data.index.tz_localize('America/New_York')  # US/Eastern, UTC
#      98 if do_optimize:          # parallel parameter search
#
# KeyError: 'ESU0 FUT GLOBEX'
