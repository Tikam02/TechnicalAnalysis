# %% [markdown]
# ## Sectoral Analysis
# - https://readmedium.com/en/https:/medium.datadriveninvestor.com/financial-market-dynamics-made-simple-one-visualization-to-rule-them-all-f154ab316ca5

# %%
import os
import pandas as pd
import yfinance as yf

INPUT_CSV_PATH = '../data/updated_niftymidcap50_stocks.csv'  # Replace with the actual path to your CSV file

def get_ticker_data(tickers: list):
    '''
    Obtain the price data for all tickers specified. The outcome is a csv file
    of price data for each ticker in the data folder.
    
    Parameters
    ----------
    tickers : list
        A list of the tickers to download the data for
    '''
        
    data = yf.download(
        tickers=tickers,
        interval='1d',
        group_by='ticker',
        threads=True,
    )
    
    data = data.T
    all_downloaded_tickers = list(set([idx[0] for idx in data.index]))
    
    for ticker in all_downloaded_tickers:

        df = data.loc[ticker, :].T.sort_index().dropna()
        df.to_csv(f'data/{ticker}.csv', index=True)
            
    return


def read_tickers_from_csv(csv_path: str, column_name: str = 'Symbol') -> list:
    '''
    Read tickers from an input CSV file.
    
    Parameters
    ----------
    csv_path : str
        The path to the CSV file.
    column_name : str, optional
        The name of the column containing tickers, by default 'Symbol'.
        
    Returns
    -------
    list
        A list of tickers.
    '''
    return pd.read_csv(csv_path)[column_name].tolist()


if __name__ == '__main__':
    
    # Check if a directory exists called 'data', if not, create it
    if not os.path.isdir('data'):
        os.mkdir('data')
    
    # Read tickers from the input CSV file
    input_tickers = read_tickers_from_csv(INPUT_CSV_PATH)
    
    # Download one CSV file per ticker and place it in the data directory
    get_ticker_data(input_tickers)
# Out:
# [*********************100%%**********************]  50 of 50 completed
#
# 46 Failed downloads:
# ['SRF', 'CDSL', 'LODHA', 'MAHABANK', 'ABB', 'MAHLIFE', 'STARHEALTH', 'BLUEDART', 'AVANTIFEED', 'RALLIS', 'DIVISLAB', 'GLAND', 'MANAPPURAM', 'AMBUJACEM', 'CARBORUNIV', 'LEMONTREE', 'FINCABLES', 'BALKRISIND', 'DCMSHRIRAM', 'ASIANPAINT', 'BIRLACORPN', 'TATACOMM', 'LXCHEM', 'CANBK', 'TV18BRDCST', 'IRCTC', 'FDC', 'DIXON', 'GODREJCP', 'MPHASIS', 'SKFINDIA', 'VGUARD', 'JUBLPHARMA', 'NATCOPHARM', 'CUB', 'L&TFH', 'NUVOCO', 'PIIND', 'PVRINOX', 'TRENT', 'TATAINVEST', 'RAYMOND', 'PETRONET', 'HAVELLS', 'CLEAN']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ['FSL']: Exception('%ticker%: No price data found, symbol may be delisted (1d 1925-03-26 -> 2024-03-02)')
# [**************************************************220%%***************************************************]  110 of 50 completedFailed to get ticker 'CIPLA' reason: HTTPSConnectionPool(host='www.yahoo.com', port=443): Read timed out.
# [**************************************************222%%****************************************************]  111 of 50 completedFailed to get ticker 'COFORGE' reason: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# [***************************************************224%%****************************************************]  112 of 50 completedFailed to get ticker 'APARINDS' reason: HTTPSConnectionPool(host='query1.finance.yahoo.com', port=443): Read timed out. (read timeout=30)
# [***************************************************226%%****************************************************]  113 of 50 completedFailed to get ticker 'AARTIDRUGS' reason: HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out. (read timeout=10)
# [***************************************************228%%*****************************************************]  114 of 50 completedFailed to get ticker 'NAZARA' reason: HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out. (read timeout=10)
# Failed to get ticker 'MARUTI' reason: HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out. (read timeout=10)
# [****************************************************230%%*****************************************************]  115 of 50 completedFailed to get ticker 'APOLLOHOSP' reason: HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out. (read timeout=10)
# Failed to get ticker 'ERIS' reason: HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out. (read timeout=10)
# Failed to get ticker 'APOLLOTYRE' reason: HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out. (read timeout=10)
# [*****************************************************234%%******************************************************]  117 of 50 completedFailed to get ticker 'FINPIPE' reason: HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out. (read timeout=10)
# [******************************************************238%%*******************************************************]  119 of 50 completedFailed to get ticker 'TRIDENT' reason: HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out. (read timeout=10)
# [********************************************************246%%*********************************************************]  123 of 50 completed

# %%
import numpy as np
import pandas as pd
import plotly.express as px
import plotly.io as pio
pio.renderers.default = 'browser'

INPUT_CSV_FILE = '../data/ind_nifty500list.csv'  # Replace with the actual path to your CSV file
DATA_DIR = 'data/'
CALC_DAYS = 20  # The number of days to calculate the percentage gain from

if __name__ == '__main__':
    
    # Read ticker symbols and industry information from the input CSV file
    input_data = pd.read_csv(INPUT_CSV_FILE)
    
    # Collect the growth statistics for each ticker in the list
    stats = []
    for ticker in input_data['Symbol'].tolist():
        
        try:
            df = pd.read_csv(DATA_DIR + ticker + '.csv')
            prices = df['Close'].values
            
            stats.append({
                'ticker': ticker,
                'growth': 100 * (prices[-1] / prices[-CALC_DAYS] - 1)
            })
        except Exception as e:
            print(ticker, ':', e)
        
    # Form into a dataframe so that we can add the industry information to it, 
    # and then aggregate to get the visualisation heatmap
    stats = (
        pd.DataFrame(stats)
        .merge(
            input_data[['Symbol', 'Industry']],
            left_on='ticker',
            right_on='Symbol',
            how='left',
        )
        .drop(columns='Symbol')
    )
    
    # To aggregate the metrics, we need to add flags to see if they are
    # satisfied, these are then counted in the following steps
    stats['positive'] = np.where(stats['growth'] > 0, 1, 0)
    stats['greater_than_5'] = np.where(stats['growth'] > 5, 1, 0)
    stats['greater_than_10'] = np.where(stats['growth'] > 10, 1, 0)
    stats['less_than_5'] = np.where(stats['growth'] < -5, 1, 0)
    stats['less_than_10'] = np.where(stats['growth'] < -10, 1, 0)
    
    # Get the full statistics, mapping from display : col name
    stats_to_show = {
        'Positive': 'positive',
        'Greater than 5% growth': 'greater_than_5',
        'Greater than 10% growth': 'greater_than_10',
        'Less than -5%': 'less_than_5',
        'Less than -10%': 'less_than_10',
    }
    
    # Perform the aggregation
    stats = stats.groupby('Industry').agg({
        col: 'mean' for col in stats_to_show.values()   
    })
    
    # Format the dataframe for display purposes
    stats = stats.rename(columns={v: k for k, v in stats_to_show.items()})
    stats = 100 * stats.round(2)
    
    # Produce and show the plotly figure
    fig = px.imshow(
        stats.T, 
        x=stats.index, 
        y=stats.columns,
        text_auto=True,
        color_continuous_scale='RdYlGn',
        zmin=0,
        zmax=100,
    )
    
    fig.update_layout(
        xaxis={'title': 'Industry'},
        yaxis={'title': 'Metric Type'},
        coloraxis={'colorbar': {'title': 'Amount (%)'}},
        legend={'x': 0, 'y': -0.1, 'orientation': 'h'},
        margin={'l': 50, 'r': 50, 'b': 50, 't': 25},
        width=1000,
        height=600,
    )
    
    fig.show()
# Out:
# 360ONE : [Errno 2] No such file or directory: 'data/360ONE.csv'
# 3MINDIA : [Errno 2] No such file or directory: 'data/3MINDIA.csv'
# ABB : [Errno 2] No such file or directory: 'data/ABB.csv'
# ACC : [Errno 2] No such file or directory: 'data/ACC.csv'
# AIAENG : [Errno 2] No such file or directory: 'data/AIAENG.csv'
# APLAPOLLO : [Errno 2] No such file or directory: 'data/APLAPOLLO.csv'
# AUBANK : [Errno 2] No such file or directory: 'data/AUBANK.csv'
# AARTIDRUGS : [Errno 2] No such file or directory: 'data/AARTIDRUGS.csv'
# AARTIIND : [Errno 2] No such file or directory: 'data/AARTIIND.csv'
# AAVAS : [Errno 2] No such file or directory: 'data/AAVAS.csv'
# ABBOTINDIA : [Errno 2] No such file or directory: 'data/ABBOTINDIA.csv'
# ADANIENSOL : [Errno 2] No such file or directory: 'data/ADANIENSOL.csv'
# ADANIENT : [Errno 2] No such file or directory: 'data/ADANIENT.csv'
# ADANIGREEN : [Errno 2] No such file or directory: 'data/ADANIGREEN.csv'
# ADANIPORTS : [Errno 2] No such file or directory: 'data/ADANIPORTS.csv'
# ADANIPOWER : [Errno 2] No such file or directory: 'data/ADANIPOWER.csv'
# ATGL : [Errno 2] No such file or directory: 'data/ATGL.csv'
# AWL : [Errno 2] No such file or directory: 'data/AWL.csv'
# ABCAPITAL : [Errno 2] No such file or directory: 'data/ABCAPITAL.csv'
# ABFRL : [Errno 2] No such file or directory: 'data/ABFRL.csv'
# AEGISCHEM : [Errno 2] No such file or directory: 'data/AEGISCHEM.csv'
# AETHER : [Errno 2] No such file or directory: 'data/AETHER.csv'
# AFFLE : [Errno 2] No such file or directory: 'data/AFFLE.csv'
# AJANTPHARM : [Errno 2] No such file or directory: 'data/AJANTPHARM.csv'
# APLLTD : [Errno 2] No such file or directory: 'data/APLLTD.csv'
# ALKEM : [Errno 2] No such file or directory: 'data/ALKEM.csv'
# ALKYLAMINE : [Errno 2] No such file or directory: 'data/ALKYLAMINE.csv'
# ALLCARGO : [Errno 2] No such file or directory: 'data/ALLCARGO.csv'
# ALOKINDS : [Errno 2] No such file or directory: 'data/ALOKINDS.csv'
# ARE&M : [Errno 2] No such file or directory: 'data/ARE&M.csv'
# AMBER : [Errno 2] No such file or directory: 'data/AMBER.csv'
# AMBUJACEM : [Errno 2] No such file or directory: 'data/AMBUJACEM.csv'
# ANGELONE : [Errno 2] No such file or directory: 'data/ANGELONE.csv'
# ANURAS : [Errno 2] No such file or directory: 'data/ANURAS.csv'
# APARINDS : [Errno 2] No such file or directory: 'data/APARINDS.csv'
# APOLLOHOSP : [Errno 2] No such file or directory: 'data/APOLLOHOSP.csv'
# APOLLOTYRE : [Errno 2] No such file or directory: 'data/APOLLOTYRE.csv'
# APTUS : [Errno 2] No such file or directory: 'data/APTUS.csv'
# ACI : [Errno 2] No such file or directory: 'data/ACI.csv'
# ASAHIINDIA : [Errno 2] No such file or directory: 'data/ASAHIINDIA.csv'
# ASHOKLEY : [Errno 2] No such file or directory: 'data/ASHOKLEY.csv'
# ASIANPAINT : [Errno 2] No such file or directory: 'data/ASIANPAINT.csv'
# ASTERDM : [Errno 2] No such file or directory: 'data/ASTERDM.csv'
# ASTRAL : [Errno 2] No such file or directory: 'data/ASTRAL.csv'
# ATUL : [Errno 2] No such file or directory: 'data/ATUL.csv'
# AUROPHARMA : [Errno 2] No such file or directory: 'data/AUROPHARMA.csv'
# AVANTIFEED : [Errno 2] No such file or directory: 'data/AVANTIFEED.csv'
# DMART : [Errno 2] No such file or directory: 'data/DMART.csv'
# DEVYANI : [Errno 2] No such file or directory: 'data/DEVYANI.csv'
# DIVISLAB : [Errno 2] No such file or directory: 'data/DIVISLAB.csv'
# DIXON : [Errno 2] No such file or directory: 'data/DIXON.csv'
# LALPATHLAB : [Errno 2] No such file or directory: 'data/LALPATHLAB.csv'
# DRREDDY : [Errno 2] No such file or directory: 'data/DRREDDY.csv'
# EIDPARRY : [Errno 2] No such file or directory: 'data/EIDPARRY.csv'
# EIHOTEL : [Errno 2] No such file or directory: 'data/EIHOTEL.csv'
# EPL : [Errno 2] No such file or directory: 'data/EPL.csv'
# EASEMYTRIP : [Errno 2] No such file or directory: 'data/EASEMYTRIP.csv'
# EICHERMOT : [Errno 2] No such file or directory: 'data/EICHERMOT.csv'
# ELGIEQUIP : [Errno 2] No such file or directory: 'data/ELGIEQUIP.csv'
# EMAMILTD : [Errno 2] No such file or directory: 'data/EMAMILTD.csv'
# ENDURANCE : [Errno 2] No such file or directory: 'data/ENDURANCE.csv'
# ENGINERSIN : [Errno 2] No such file or directory: 'data/ENGINERSIN.csv'
# EPIGRAL : [Errno 2] No such file or directory: 'data/EPIGRAL.csv'
# EQUITASBNK : [Errno 2] No such file or directory: 'data/EQUITASBNK.csv'
# ERIS : [Errno 2] No such file or directory: 'data/ERIS.csv'
# ESCORTS : [Errno 2] No such file or directory: 'data/ESCORTS.csv'
# EXIDEIND : [Errno 2] No such file or directory: 'data/EXIDEIND.csv'
# FDC : [Errno 2] No such file or directory: 'data/FDC.csv'
# NYKAA : [Errno 2] No such file or directory: 'data/NYKAA.csv'
# FEDERALBNK : [Errno 2] No such file or directory: 'data/FEDERALBNK.csv'
# FACT : [Errno 2] No such file or directory: 'data/FACT.csv'
# FINEORG : [Errno 2] No such file or directory: 'data/FINEORG.csv'
# FINCABLES : [Errno 2] No such file or directory: 'data/FINCABLES.csv'
# FINPIPE : [Errno 2] No such file or directory: 'data/FINPIPE.csv'
# FSL : [Errno 2] No such file or directory: 'data/FSL.csv'
# FIVESTAR : [Errno 2] No such file or directory: 'data/FIVESTAR.csv'
# FORTIS : [Errno 2] No such file or directory: 'data/FORTIS.csv'
# GRINFRA : [Errno 2] No such file or directory: 'data/GRINFRA.csv'
# GAIL : [Errno 2] No such file or directory: 'data/GAIL.csv'
# GMMPFAUDLR : [Errno 2] No such file or directory: 'data/GMMPFAUDLR.csv'
# GMRINFRA : [Errno 2] No such file or directory: 'data/GMRINFRA.csv'
# GALAXYSURF : [Errno 2] No such file or directory: 'data/GALAXYSURF.csv'
# GICRE : [Errno 2] No such file or directory: 'data/GICRE.csv'
# GILLETTE : [Errno 2] No such file or directory: 'data/GILLETTE.csv'
# GLAND : [Errno 2] No such file or directory: 'data/GLAND.csv'
# GLAXO : [Errno 2] No such file or directory: 'data/GLAXO.csv'
# GLS : [Errno 2] No such file or directory: 'data/GLS.csv'
# GLENMARK : [Errno 2] No such file or directory: 'data/GLENMARK.csv'
# MEDANTA : [Errno 2] No such file or directory: 'data/MEDANTA.csv'
# GOCOLORS : [Errno 2] No such file or directory: 'data/GOCOLORS.csv'
# GPIL : [Errno 2] No such file or directory: 'data/GPIL.csv'
# GODFRYPHLP : [Errno 2] No such file or directory: 'data/GODFRYPHLP.csv'
# GODREJCP : [Errno 2] No such file or directory: 'data/GODREJCP.csv'
# GODREJIND : [Errno 2] No such file or directory: 'data/GODREJIND.csv'
# GODREJPROP : [Errno 2] No such file or directory: 'data/GODREJPROP.csv'
# GRANULES : [Errno 2] No such file or directory: 'data/GRANULES.csv'
# GRAPHITE : [Errno 2] No such file or directory: 'data/GRAPHITE.csv'
# GRASIM : [Errno 2] No such file or directory: 'data/GRASIM.csv'
# GESHIP : [Errno 2] No such file or directory: 'data/GESHIP.csv'
# GRINDWELL : [Errno 2] No such file or directory: 'data/GRINDWELL.csv'
# GUJALKALI : [Errno 2] No such file or directory: 'data/GUJALKALI.csv'
# GAEL : [Errno 2] No such file or directory: 'data/GAEL.csv'
# FLUOROCHEM : [Errno 2] No such file or directory: 'data/FLUOROCHEM.csv'
# GUJGASLTD : [Errno 2] No such file or directory: 'data/GUJGASLTD.csv'
# GNFC : [Errno 2] No such file or directory: 'data/GNFC.csv'
# GPPL : [Errno 2] No such file or directory: 'data/GPPL.csv'
# GSFC : [Errno 2] No such file or directory: 'data/GSFC.csv'
# GSPL : [Errno 2] No such file or directory: 'data/GSPL.csv'
# HEG : [Errno 2] No such file or directory: 'data/HEG.csv'
# HCLTECH : [Errno 2] No such file or directory: 'data/HCLTECH.csv'
# HDFCAMC : [Errno 2] No such file or directory: 'data/HDFCAMC.csv'
# HDFCBANK : [Errno 2] No such file or directory: 'data/HDFCBANK.csv'
# HDFCLIFE : [Errno 2] No such file or directory: 'data/HDFCLIFE.csv'
# HFCL : [Errno 2] No such file or directory: 'data/HFCL.csv'
# HLEGLAS : [Errno 2] No such file or directory: 'data/HLEGLAS.csv'
# HAPPSTMNDS : [Errno 2] No such file or directory: 'data/HAPPSTMNDS.csv'
# HAVELLS : [Errno 2] No such file or directory: 'data/HAVELLS.csv'
# HEROMOTOCO : [Errno 2] No such file or directory: 'data/HEROMOTOCO.csv'
# HINDALCO : [Errno 2] No such file or directory: 'data/HINDALCO.csv'
# HAL : [Errno 2] No such file or directory: 'data/HAL.csv'
# HINDCOPPER : [Errno 2] No such file or directory: 'data/HINDCOPPER.csv'
# HINDPETRO : [Errno 2] No such file or directory: 'data/HINDPETRO.csv'
# HINDUNILVR : [Errno 2] No such file or directory: 'data/HINDUNILVR.csv'
# HINDZINC : [Errno 2] No such file or directory: 'data/HINDZINC.csv'
# POWERINDIA : [Errno 2] No such file or directory: 'data/POWERINDIA.csv'
# HOMEFIRST : [Errno 2] No such file or directory: 'data/HOMEFIRST.csv'
# HONAUT : [Errno 2] No such file or directory: 'data/HONAUT.csv'
# HUDCO : [Errno 2] No such file or directory: 'data/HUDCO.csv'
# ICICIBANK : [Errno 2] No such file or directory: 'data/ICICIBANK.csv'
# ICICIGI : [Errno 2] No such file or directory: 'data/ICICIGI.csv'
# ICICIPRULI : [Errno 2] No such file or directory: 'data/ICICIPRULI.csv'
# ISEC : [Errno 2] No such file or directory: 'data/ISEC.csv'
# IDBI : [Errno 2] No such file or directory: 'data/IDBI.csv'
# MARICO : [Errno 2] No such file or directory: 'data/MARICO.csv'
# MARUTI : [Errno 2] No such file or directory: 'data/MARUTI.csv'
# MASTEK : [Errno 2] No such file or directory: 'data/MASTEK.csv'
# MFSL : [Errno 2] No such file or directory: 'data/MFSL.csv'
# MAXHEALTH : [Errno 2] No such file or directory: 'data/MAXHEALTH.csv'
# MAZDOCK : [Errno 2] No such file or directory: 'data/MAZDOCK.csv'
# MEDPLUS : [Errno 2] No such file or directory: 'data/MEDPLUS.csv'
# METROBRAND : [Errno 2] No such file or directory: 'data/METROBRAND.csv'
# METROPOLIS : [Errno 2] No such file or directory: 'data/METROPOLIS.csv'
# MINDACORP : [Errno 2] No such file or directory: 'data/MINDACORP.csv'
# MSUMI : [Errno 2] No such file or directory: 'data/MSUMI.csv'
# MOTILALOFS : [Errno 2] No such file or directory: 'data/MOTILALOFS.csv'
# MPHASIS : [Errno 2] No such file or directory: 'data/MPHASIS.csv'
# MCX : [Errno 2] No such file or directory: 'data/MCX.csv'
# MUTHOOTFIN : [Errno 2] No such file or directory: 'data/MUTHOOTFIN.csv'
# NATCOPHARM : [Errno 2] No such file or directory: 'data/NATCOPHARM.csv'
# NBCC : [Errno 2] No such file or directory: 'data/NBCC.csv'
# NCC : [Errno 2] No such file or directory: 'data/NCC.csv'
# NHPC : [Errno 2] No such file or directory: 'data/NHPC.csv'
# NLCINDIA : [Errno 2] No such file or directory: 'data/NLCINDIA.csv'
# NMDC : [Errno 2] No such file or directory: 'data/NMDC.csv'
# NSLNISP : [Errno 2] No such file or directory: 'data/NSLNISP.csv'
# NTPC : [Errno 2] No such file or directory: 'data/NTPC.csv'
# NH : [Errno 2] No such file or directory: 'data/NH.csv'
# NATIONALUM : [Errno 2] No such file or directory: 'data/NATIONALUM.csv'
# NAVINFLUOR : [Errno 2] No such file or directory: 'data/NAVINFLUOR.csv'
# NAZARA : [Errno 2] No such file or directory: 'data/NAZARA.csv'
# NESTLEIND : [Errno 2] No such file or directory: 'data/NESTLEIND.csv'
# NETWORK18 : [Errno 2] No such file or directory: 'data/NETWORK18.csv'
# NAM-INDIA : [Errno 2] No such file or directory: 'data/NAM-INDIA.csv'
# NUVOCO : [Errno 2] No such file or directory: 'data/NUVOCO.csv'
# OBEROIRLTY : [Errno 2] No such file or directory: 'data/OBEROIRLTY.csv'
# ONGC : [Errno 2] No such file or directory: 'data/ONGC.csv'
# OIL : [Errno 2] No such file or directory: 'data/OIL.csv'
# OLECTRA : [Errno 2] No such file or directory: 'data/OLECTRA.csv'
# PAYTM : [Errno 2] No such file or directory: 'data/PAYTM.csv'
# OFSS : [Errno 2] No such file or directory: 'data/OFSS.csv'
# ORIENTELEC : [Errno 2] No such file or directory: 'data/ORIENTELEC.csv'
# POLICYBZR : [Errno 2] No such file or directory: 'data/POLICYBZR.csv'
# PCBL : [Errno 2] No such file or directory: 'data/PCBL.csv'
# PIIND : [Errno 2] No such file or directory: 'data/PIIND.csv'
# PNBHOUSING : [Errno 2] No such file or directory: 'data/PNBHOUSING.csv'
# PNCINFRA : [Errno 2] No such file or directory: 'data/PNCINFRA.csv'
# PVRINOX : [Errno 2] No such file or directory: 'data/PVRINOX.csv'
# PAGEIND : [Errno 2] No such file or directory: 'data/PAGEIND.csv'
# PATANJALI : [Errno 2] No such file or directory: 'data/PATANJALI.csv'
# PERSISTENT : [Errno 2] No such file or directory: 'data/PERSISTENT.csv'
# PETRONET : [Errno 2] No such file or directory: 'data/PETRONET.csv'
# PFIZER : [Errno 2] No such file or directory: 'data/PFIZER.csv'
# PHOENIXLTD : [Errno 2] No such file or directory: 'data/PHOENIXLTD.csv'
# PIDILITIND : [Errno 2] No such file or directory: 'data/PIDILITIND.csv'
# PEL : [Errno 2] No such file or directory: 'data/PEL.csv'
# PPLPHARMA : [Errno 2] No such file or directory: 'data/PPLPHARMA.csv'
# POLYMED : [Errno 2] No such file or directory: 'data/POLYMED.csv'
# POLYCAB : [Errno 2] No such file or directory: 'data/POLYCAB.csv'
# POLYPLEX : [Errno 2] No such file or directory: 'data/POLYPLEX.csv'
# POONAWALLA : [Errno 2] No such file or directory: 'data/POONAWALLA.csv'
# PFC : [Errno 2] No such file or directory: 'data/PFC.csv'
# POWERGRID : [Errno 2] No such file or directory: 'data/POWERGRID.csv'
# PRAJIND : [Errno 2] No such file or directory: 'data/PRAJIND.csv'
# PRESTIGE : [Errno 2] No such file or directory: 'data/PRESTIGE.csv'
# PRINCEPIPE : [Errno 2] No such file or directory: 'data/PRINCEPIPE.csv'
# PRSMJOHNSN : [Errno 2] No such file or directory: 'data/PRSMJOHNSN.csv'
# PGHL : [Errno 2] No such file or directory: 'data/PGHL.csv'
# PGHH : [Errno 2] No such file or directory: 'data/PGHH.csv'
# PNB : [Errno 2] No such file or directory: 'data/PNB.csv'
# QUESS : [Errno 2] No such file or directory: 'data/QUESS.csv'
# RBLBANK : [Errno 2] No such file or directory: 'data/RBLBANK.csv'
# RECLTD : [Errno 2] No such file or directory: 'data/RECLTD.csv'
# RHIM : [Errno 2] No such file or directory: 'data/RHIM.csv'
# RITES : [Errno 2] No such file or directory: 'data/RITES.csv'
# RADICO : [Errno 2] No such file or directory: 'data/RADICO.csv'
# RVNL : [Errno 2] No such file or directory: 'data/RVNL.csv'
# RAIN : [Errno 2] No such file or directory: 'data/RAIN.csv'
# RAINBOW : [Errno 2] No such file or directory: 'data/RAINBOW.csv'
# RAJESHEXPO : [Errno 2] No such file or directory: 'data/RAJESHEXPO.csv'
# RALLIS : [Errno 2] No such file or directory: 'data/RALLIS.csv'
# RCF : [Errno 2] No such file or directory: 'data/RCF.csv'
# RATNAMANI : [Errno 2] No such file or directory: 'data/RATNAMANI.csv'
# RTNINDIA : [Errno 2] No such file or directory: 'data/RTNINDIA.csv'
# RAYMOND : [Errno 2] No such file or directory: 'data/RAYMOND.csv'
# REDINGTON : [Errno 2] No such file or directory: 'data/REDINGTON.csv'
# RELAXO : [Errno 2] No such file or directory: 'data/RELAXO.csv'
# RELIANCE : [Errno 2] No such file or directory: 'data/RELIANCE.csv'
# RBA : [Errno 2] No such file or directory: 'data/RBA.csv'
# ROSSARI : [Errno 2] No such file or directory: 'data/ROSSARI.csv'
# ROUTE : [Errno 2] No such file or directory: 'data/ROUTE.csv'
# SBICARD : [Errno 2] No such file or directory: 'data/SBICARD.csv'
# SBILIFE : [Errno 2] No such file or directory: 'data/SBILIFE.csv'
# SJVN : [Errno 2] No such file or directory: 'data/SJVN.csv'
# SKFINDIA : [Errno 2] No such file or directory: 'data/SKFINDIA.csv'
# SRF : [Errno 2] No such file or directory: 'data/SRF.csv'
# SAFARI : [Errno 2] No such file or directory: 'data/SAFARI.csv'
# MOTHERSON : [Errno 2] No such file or directory: 'data/MOTHERSON.csv'
# SANOFI : [Errno 2] No such file or directory: 'data/SANOFI.csv'
# SAPPHIRE : [Errno 2] No such file or directory: 'data/SAPPHIRE.csv'
# SAREGAMA : [Errno 2] No such file or directory: 'data/SAREGAMA.csv'
# SCHAEFFLER : [Errno 2] No such file or directory: 'data/SCHAEFFLER.csv'
# SHARDACROP : [Errno 2] No such file or directory: 'data/SHARDACROP.csv'
# SFL : [Errno 2] No such file or directory: 'data/SFL.csv'
# SHOPERSTOP : [Errno 2] No such file or directory: 'data/SHOPERSTOP.csv'
# SHREECEM : [Errno 2] No such file or directory: 'data/SHREECEM.csv'
# RENUKA : [Errno 2] No such file or directory: 'data/RENUKA.csv'
# SHRIRAMFIN : [Errno 2] No such file or directory: 'data/SHRIRAMFIN.csv'
# SHYAMMETL : [Errno 2] No such file or directory: 'data/SHYAMMETL.csv'
# SIEMENS : [Errno 2] No such file or directory: 'data/SIEMENS.csv'
# SOBHA : [Errno 2] No such file or directory: 'data/SOBHA.csv'
# SOLARINDS : [Errno 2] No such file or directory: 'data/SOLARINDS.csv'
# SONACOMS : [Errno 2] No such file or directory: 'data/SONACOMS.csv'
# SONATSOFTW : [Errno 2] No such file or directory: 'data/SONATSOFTW.csv'
# STARHEALTH : [Errno 2] No such file or directory: 'data/STARHEALTH.csv'
# SBIN : [Errno 2] No such file or directory: 'data/SBIN.csv'
# SAIL : [Errno 2] No such file or directory: 'data/SAIL.csv'
# SWSOLAR : [Errno 2] No such file or directory: 'data/SWSOLAR.csv'
# STLTECH : [Errno 2] No such file or directory: 'data/STLTECH.csv'
# SUMICHEM : [Errno 2] No such file or directory: 'data/SUMICHEM.csv'
# SPARC : [Errno 2] No such file or directory: 'data/SPARC.csv'
# SUNPHARMA : [Errno 2] No such file or directory: 'data/SUNPHARMA.csv'
# SUNTV : [Errno 2] No such file or directory: 'data/SUNTV.csv'
# SUNDARMFIN : [Errno 2] No such file or directory: 'data/SUNDARMFIN.csv'
# SUNDRMFAST : [Errno 2] No such file or directory: 'data/SUNDRMFAST.csv'
# SUNTECK : [Errno 2] No such file or directory: 'data/SUNTECK.csv'
# SUPRAJIT : [Errno 2] No such file or directory: 'data/SUPRAJIT.csv'
# SUPREMEIND : [Errno 2] No such file or directory: 'data/SUPREMEIND.csv'
# SUVENPHAR : [Errno 2] No such file or directory: 'data/SUVENPHAR.csv'
# SUZLON : [Errno 2] No such file or directory: 'data/SUZLON.csv'
# SWANENERGY : [Errno 2] No such file or directory: 'data/SWANENERGY.csv'
# SYMPHONY : [Errno 2] No such file or directory: 'data/SYMPHONY.csv'
# SYNGENE : [Errno 2] No such file or directory: 'data/SYNGENE.csv'
# SYRMA : [Errno 2] No such file or directory: 'data/SYRMA.csv'
# TTKPRESTIG : [Errno 2] No such file or directory: 'data/TTKPRESTIG.csv'
# TV18BRDCST : [Errno 2] No such file or directory: 'data/TV18BRDCST.csv'
# TVSMOTOR : [Errno 2] No such file or directory: 'data/TVSMOTOR.csv'
# TANLA : [Errno 2] No such file or directory: 'data/TANLA.csv'
# TATACHEM : [Errno 2] No such file or directory: 'data/TATACHEM.csv'
# TATACOMM : [Errno 2] No such file or directory: 'data/TATACOMM.csv'
# TCS : [Errno 2] No such file or directory: 'data/TCS.csv'
# TATACONSUM : [Errno 2] No such file or directory: 'data/TATACONSUM.csv'
# TATAELXSI : [Errno 2] No such file or directory: 'data/TATAELXSI.csv'
# TATAINVEST : [Errno 2] No such file or directory: 'data/TATAINVEST.csv'
# TATAMTRDVR : [Errno 2] No such file or directory: 'data/TATAMTRDVR.csv'
# TATAMOTORS : [Errno 2] No such file or directory: 'data/TATAMOTORS.csv'
# TATAPOWER : [Errno 2] No such file or directory: 'data/TATAPOWER.csv'
# TATASTEEL : [Errno 2] No such file or directory: 'data/TATASTEEL.csv'
# TTML : [Errno 2] No such file or directory: 'data/TTML.csv'
# TEAMLEASE : [Errno 2] No such file or directory: 'data/TEAMLEASE.csv'
# TECHM : [Errno 2] No such file or directory: 'data/TECHM.csv'
# TEJASNET : [Errno 2] No such file or directory: 'data/TEJASNET.csv'
# NIACL : [Errno 2] No such file or directory: 'data/NIACL.csv'
# RAMCOCEM : [Errno 2] No such file or directory: 'data/RAMCOCEM.csv'
# THERMAX : [Errno 2] No such file or directory: 'data/THERMAX.csv'
# TIMKEN : [Errno 2] No such file or directory: 'data/TIMKEN.csv'
# TITAN : [Errno 2] No such file or directory: 'data/TITAN.csv'
# TORNTPHARM : [Errno 2] No such file or directory: 'data/TORNTPHARM.csv'
# TORNTPOWER : [Errno 2] No such file or directory: 'data/TORNTPOWER.csv'
# TRENT : [Errno 2] No such file or directory: 'data/TRENT.csv'
# TRIDENT : [Errno 2] No such file or directory: 'data/TRIDENT.csv'
# TRIVENI : [Errno 2] No such file or directory: 'data/TRIVENI.csv'
# TRITURBINE : [Errno 2] No such file or directory: 'data/TRITURBINE.csv'
# TIINDIA : [Errno 2] No such file or directory: 'data/TIINDIA.csv'
# UCOBANK : [Errno 2] No such file or directory: 'data/UCOBANK.csv'
# UNOMINDA : [Errno 2] No such file or directory: 'data/UNOMINDA.csv'
# UPL : [Errno 2] No such file or directory: 'data/UPL.csv'
# UTIAMC : [Errno 2] No such file or directory: 'data/UTIAMC.csv'
# UJJIVANSFB : [Errno 2] No such file or directory: 'data/UJJIVANSFB.csv'
# ULTRACEMCO : [Errno 2] No such file or directory: 'data/ULTRACEMCO.csv'
# UNIONBANK : [Errno 2] No such file or directory: 'data/UNIONBANK.csv'
# UBL : [Errno 2] No such file or directory: 'data/UBL.csv'
# MCDOWELL-N : [Errno 2] No such file or directory: 'data/MCDOWELL-N.csv'
# USHAMART : [Errno 2] No such file or directory: 'data/USHAMART.csv'
# VGUARD : [Errno 2] No such file or directory: 'data/VGUARD.csv'
# VMART : [Errno 2] No such file or directory: 'data/VMART.csv'
# VIPIND : [Errno 2] No such file or directory: 'data/VIPIND.csv'
# VAIBHAVGBL : [Errno 2] No such file or directory: 'data/VAIBHAVGBL.csv'
# VTL : [Errno 2] No such file or directory: 'data/VTL.csv'
# VARROC : [Errno 2] No such file or directory: 'data/VARROC.csv'
# VBL : [Errno 2] No such file or directory: 'data/VBL.csv'
# MANYAVAR : [Errno 2] No such file or directory: 'data/MANYAVAR.csv'
# VEDL : [Errno 2] No such file or directory: 'data/VEDL.csv'
# VIJAYA : [Errno 2] No such file or directory: 'data/VIJAYA.csv'
# VINATIORGA : [Errno 2] No such file or directory: 'data/VINATIORGA.csv'
# IDEA : [Errno 2] No such file or directory: 'data/IDEA.csv'
# VOLTAS : [Errno 2] No such file or directory: 'data/VOLTAS.csv'
# WELCORP : [Errno 2] No such file or directory: 'data/WELCORP.csv'
# WELSPUNLIV : [Errno 2] No such file or directory: 'data/WELSPUNLIV.csv'
# WESTLIFE : [Errno 2] No such file or directory: 'data/WESTLIFE.csv'
# WHIRLPOOL : [Errno 2] No such file or directory: 'data/WHIRLPOOL.csv'
# WIPRO : [Errno 2] No such file or directory: 'data/WIPRO.csv'
# YESBANK : [Errno 2] No such file or directory: 'data/YESBANK.csv'
# ZFCVINDIA : [Errno 2] No such file or directory: 'data/ZFCVINDIA.csv'
# ZEEL : [Errno 2] No such file or directory: 'data/ZEEL.csv'
# ZENSARTECH : [Errno 2] No such file or directory: 'data/ZENSARTECH.csv'
# ZOMATO : [Errno 2] No such file or directory: 'data/ZOMATO.csv'
# ZYDUSLIFE : [Errno 2] No such file or directory: 'data/ZYDUSLIFE.csv'
# ZYDUSWELL : [Errno 2] No such file or directory: 'data/ZYDUSWELL.csv'
# ECLERX : [Errno 2] No such file or directory: 'data/ECLERX.csv'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_41819/1730176987.py in ?()
#      30
#      31     # Form into a dataframe so that we can add the industry information to it,
#      32     # and then aggregate to get the visualisation heatmap
#      33     stats = (
# ---> 34         pd.DataFrame(stats)
#      35         .merge(
#      36             input_data[['Symbol', 'Industry']],
#      37             left_on='ticker',
#
# ~/stock-market/env3/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10089         validate: str | None = None,
#   10090     ) -> DataFrame:
#   10091         from pandas.core.reshape.merge import merge
#   10092
# > 10093         return merge(
#   10094             self,
#   10095             right,
#   10096             how=how,
#
# ~/stock-market/env3/lib/python3.10/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     106     copy: bool = True,
#     107     indicator: bool = False,
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#
# ~/stock-market/env3/lib/python3.10/site-packages/pandas/core/reshape/merge.py in ?(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     699         (
#     700             self.left_join_keys,
#     701             self.right_join_keys,
#     702             self.join_names,
# --> 703         ) = self._get_merge_keys()
#     704
#     705         # validate the merge keys dtypes. We may need to coerce
#     706         # to avoid incompatible dtypes
#
# ~/stock-market/env3/lib/python3.10/site-packages/pandas/core/reshape/merge.py in ?(self)
#    1175                     if lk is not None:
#    1176                         # Then we're either Hashable or a wrong-length arraylike,
#    1177                         #  the latter of which will raise
#    1178                         lk = cast(Hashable, lk)
# -> 1179                         left_keys.append(left._get_label_or_level_values(lk))
#    1180                         join_names.append(lk)
#    1181                     else:
#    1182                         # work-around for merge_asof(left_index=True)
#
# ~/stock-market/env3/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1846                 .get_level_values(key)  # type: ignore[assignment]
#    1847                 ._values
#    1848             )
#    1849         else:
# -> 1850             raise KeyError(key)
#    1851
#    1852         # Check for duplicates
#    1853         if values.ndim > 1:
#
# KeyError: 'ticker'
