# %%
# !pip install fredapi > /dev/null

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

sns.set_style("white")

#pd.set_option('max_columns', 500)

pd.options.display.max_columns = 500


from fredapi import Fred

fred_key = '9f15793bead175458dc9042d8802de7c'
api_key = os.getenv("fred_key")


fred = Fred(api_key=fred_key)
#The FRED api key can be obtained from (https://fred.stlouisfed.org/docs/api/api_key.html)

# %%
icpi = fred.get_series(series_id='INDCPIALLMINMEI') # Consumer price index all items
inr_to_usd_spot = fred.get_series(series_id='DEXINUS') # inr to usd spot price daily
india_property = fred.get_series(series_id='QINR628BIS') # india real property prices
india_inflation = fred.get_series(series_id='FPCPITOTLZGIND') # inflation rates
india_gdp = fred.get_series(series_id='NGDPRNSAXDCINQ') # real GDP for india
india_youth_unemp = fred.get_series(series_id='SLUEM1524ZSIND') # Indian youth unemployment rate
india_emp_to_population = fred.get_series(series_id='SLEMPTOTLSPZSIND') # employment to Population
india_stock_to_gdp = fred.get_series(series_id='DDDM01INA156NWDB') # stock market capitalisation to GDP of india
india_int_rates = fred.get_series(series_id='INTDSRINM193N') # interest rates for India
india_10yr_bonds_rate = fred.get_series(series_id='INDIRLTLT01STM') # 10 year indian bond rate
india_export_value = fred.get_series(series_id='INDEXPORTQDSMEI') # Value of Exports (Goods and Services)
india_imp_exp_ratio = fred.get_series(series_id='XTEITT01INM156S') # Ratio of Export to Import
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File /usr/lib/python3.10/urllib/request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File /usr/lib/python3.10/http/client.py:1283, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1282 """Send a complete request to the server."""
# -> 1283 self._send_request(method, url, body, headers, encode_chunked)
#
# File /usr/lib/python3.10/http/client.py:1329, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1328     body = _encode(body, 'body')
# -> 1329 self.endheaders(body, encode_chunked=encode_chunked)
#
# ...

# %% [markdown]
# ### GDP of India has seen a steady growth since 2005
# Since 2005, India's Gross Domestic Product (GDP) has exhibited a combination of robust growth and occasional economic challenges. The country experienced a period of steady expansion during the mid-2000s and early 2010s, positioning itself as one of the world's fastest-growing major economies.

# %%
india_gdp.plot(title='GDP of INDIA',figsize = (14,5),x='year',y='GDP',color='#8d0d87d0',lw=4,kind='area')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 india_gdp.plot(title='GDP of INDIA',figsize = (14,5),x='year',y='GDP',color='#8d0d87d0',lw=4,kind='area')
#
# NameError: name 'india_gdp' is not defined

# %% [markdown]
# This growth was driven by favorable demographics, increased foreign direct investments, and a thriving services sector. However, the latter part of the 2010s saw a slowdown in economic growth due to various factors such as domestic economic reforms, global economic fluctuations, and changes in international trade dynamics.
#
# Despite these fluctuations, India's economy has continued to hold significance on the global stage. The trajectory of India's GDP remains influenced by multiple factors, including government policies and responses to evolving economic challenges.

# %% [markdown]
# ## Growth of Export value

# %% [markdown]
# Since the year 2000, India has witnessed a remarkable and consistent growth in its export value, bolstering its position as a global economic player. Driven by various factors such as liberalization, globalization, and advancements in technology, Indian exports have expanded across diverse sectors. The country's skilled workforce, competitive manufacturing, and growing services sector have played pivotal roles in this ascent. Additionally, India's strategic geographical location and access to major international markets have further facilitated trade.

# %%
india_export_value.plot(title='Exports Value',figsize = (14,5),x='year',y='Value',color='#8d0d87d0',lw=4)
# Out:
# <Axes: title={'center': 'Exports Value'}>

# %% [markdown]
# Over the years, the government's proactive policies, including export promotion schemes and trade agreements, have encouraged businesses to explore overseas markets. As a result, India's export value has surged, showcasing the nation's resilience and adaptability in the ever-evolving global economy.

# %% [markdown]
# # Ratio of Export vs Import

# %% [markdown]
# India has generally maintained a trade deficit, which means its imports have exceeded its exports. The ratio of exports to imports, commonly known as the trade balance, fluctuated over the years due to various economic factors and global trends. Until 1991, India followed a relatively protectionist trade policy, leading to limited export opportunities.
#
# However, post-1991 economic reforms, which liberalized the Indian economy, set the stage for increased exports. The country experienced steady growth in exports over the following decades. Despite this growth, imports also surged, often driven by the rising domestic demand for consumer goods, raw materials, and capital equipment.

# %%
india_imp_exp_ratio.plot(title='Export vs Imports',figsize = (14,5),x='year',y='Value',color='#8d0d87d0',lw=4)
# Out:
# <Axes: title={'center': 'Export vs Imports'}>

# %% [markdown]
# In recent years, India has been trying to address its trade imbalance through various initiatives like "Make in India" and increasing focus on export-oriented sectors. By promoting manufacturing, services, and technology-driven industries, the country aims to boost exports and reduce its reliance on imports.

# %% [markdown]
# # Comparing INR vs USD, A direct comparison of strength over one another

# %% [markdown]
# Since 1970, the trend of the Indian Rupee (INR) against the United States Dollar (USD) has been dynamic, reflecting the ever-changing economic landscape and global market conditions. The INR was initially pegged to a fixed exchange rate against the USD, but India's economic reforms in 1991 led to a transition to a more flexible exchange rate system.
#
# Throughout the years, the INR has experienced periods of appreciation and depreciation against the USD, driven by various factors like international economic trends, trade dynamics, capital flows, and domestic economic performance.

# %%
inr_to_usd_spot.plot(title='INR vs USD Daily rate',figsize = (14,5),x='year',y='Rate',color='#8d0d87')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 inr_to_usd_spot.plot(title='INR vs USD Daily rate',figsize = (14,5),x='year',y='Rate',color='#8d0d87')
#
# NameError: name 'inr_to_usd_spot' is not defined

# %%
import plotly.express as px

# Assuming your DataFrame looks like this:
# inr_to_usd_spot = pd.DataFrame({'year': [2021, 2022, 2023],
#                                 'Rate': [73.5, 74.2, 75.0]})

# Create an interactive line plot using Plotly Express
fig = px.line(inr_to_usd_spot, x='year', y='Rate', title='INR vs USD Daily rate',
              labels={'Rate': 'Exchange Rate (INR to USD)'},
              line_shape='linear', line_dash='solid', line_color='#8d0d87')

# Update layout for better appearance
fig.update_layout(title_text='INR vs USD Daily Rate',
                  xaxis_title='Year',
                  yaxis_title='Exchange Rate (INR to USD)',
                  template='plotly_dark',  # You can choose a different template
                  margin=dict(l=20, r=20, t=40, b=20),  # Adjust margins
                  )

# Show the plot
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       1 import plotly.express as px
#       3 # Assuming your DataFrame looks like this:
#       4 # inr_to_usd_spot = pd.DataFrame({'year': [2021, 2022, 2023],
#       5 #                                 'Rate': [73.5, 74.2, 75.0]})
#       6
#       7 # Create an interactive line plot using Plotly Express
# ----> 8 fig = px.line(inr_to_usd_spot, x='year', y='Rate', title='INR vs USD Daily rate',
#       9               labels={'Rate': 'Exchange Rate (INR to USD)'},
#      10               line_shape='linear', line_dash='solid', line_color='#8d0d87')
#      12 # Update layout for better appearance
#      13 fig.update_layout(title_text='INR vs USD Daily Rate',
#      14                   xaxis_title='Year',
#      15                   yaxis_title='Exchange Rate (INR to USD)',
# ...
