# %%
import pandas as pd
# Read the CSV file
df = pd.read_csv('./ind_niftymicrocap250_list.csv')

# Extract the 'Symbol' column and append ".NS" to each symbol
symbols = [symbol + '.NS' for symbol in df['Symbol']]

# Save the list of symbols to a file in the specified format
output_file = 'niftymicrocap250.txt'
with open(output_file, 'w') as file:
    file.write(str(symbols))

print(f"Symbol list saved to {output_file}")
# Out:
# Symbol list saved to niftymicrocap250.txt

# %%
# Define the path to your input and output text files
input_file_path = 'niftysmallcap500.txt'
output_file_path = 'formatted_niftysmall500.txt'


# Read stock symbols from the input text file into a single line
with open(input_file_path, 'r') as input_file:
    stock_symbols_line = input_file.read()

# Split the line into a list of stock symbols
stock_symbols_list = stock_symbols_line.split()

# Print the resulting list vertically
print("Stock Symbols List:")
for symbol in stock_symbols_list:
    print(symbol)

# Write the list to the output text file
with open(output_file_path, 'w') as output_file:
    for symbol in stock_symbols_list:
        output_file.write(symbol + '\n')

print(f"Stock symbols list has been written to {output_file_path}")
# Out:
# Stock Symbols List:
# ['360ONE.NS',
# '3MINDIA.NS',
# 'ABB.NS',
# 'ACC.NS',
# 'AIAENG.NS',
# 'APLAPOLLO.NS',
# 'AUBANK.NS',
# 'AARTIDRUGS.NS',
# 'AARTIIND.NS',
# 'AAVAS.NS',
# 'ABBOTINDIA.NS',
# 'ADANIENSOL.NS',
# 'ADANIENT.NS',
# 'ADANIGREEN.NS',
# 'ADANIPORTS.NS',
# 'ADANIPOWER.NS',
# 'ATGL.NS',
# 'AWL.NS',
# 'ABCAPITAL.NS',
# 'ABFRL.NS',
# 'AEGISCHEM.NS',
# 'AETHER.NS',
# 'AFFLE.NS',
# 'AJANTPHARM.NS',
# 'APLLTD.NS',
# 'ALKEM.NS',
# 'ALKYLAMINE.NS',
# 'ALLCARGO.NS',
# 'ALOKINDS.NS',
# 'ARE&M.NS',
# 'AMBER.NS',
# 'AMBUJACEM.NS',
# 'ANGELONE.NS',
# 'ANURAS.NS',
# 'APARINDS.NS',
# 'APOLLOHOSP.NS',
# 'APOLLOTYRE.NS',
# 'APTUS.NS',
# 'ACI.NS',
# 'ASAHIINDIA.NS',
# 'ASHOKLEY.NS',
# 'ASIANPAINT.NS',
# 'ASTERDM.NS',
# 'ASTRAL.NS',
# 'ATUL.NS',
# 'AUROPHARMA.NS',
# 'AVANTIFEED.NS',
# 'DMART.NS',
# 'AXISBANK.NS',
# 'BEML.NS',
# 'BLS.NS',
# 'BSE.NS',
# 'BAJAJ-AUTO.NS',
# 'BAJFINANCE.NS',
# 'BAJAJFINSV.NS',
# 'BAJAJHLDNG.NS',
# 'BALAMINES.NS',
# 'BALKRISIND.NS',
# 'BALRAMCHIN.NS',
# ...

# %%
# Define the path to your input text file
input_file_path = './niftymicrocap250.txt'
output_file_path = 'final_microcap_250.txt'

# Read stock symbols from the input text file into a string
with open(input_file_path, 'r') as input_file:
    input_symbols = input_file.read()

# Remove single quotes and commas
cleaned_symbols = input_symbols.replace("'", "").replace(",", "")

# Split the cleaned string into a list of stock symbols
stock_symbols_list = cleaned_symbols.split()

# Print the resulting list vertically
print("Stock Symbols List:")
for symbol in stock_symbols_list:
    print(symbol)

# Write the list to the output text file
with open(output_file_path, 'w') as output_file:
    for symbol in stock_symbols_list:
        output_file.write(symbol + '\n')

print(f"Stock symbols list has been written to {output_file_path}")
# Out:
# Stock Symbols List:
# [AGI.NS
# AARTIPHARM.NS
# ACCELYA.NS
# ACE.NS
# ADVENZYMES.NS
# AHLUCONT.NS
# ACLGATI.NS
# AMIORG.NS
# ANANDRATHI.NS
# ANANTRAJ.NS
# APCOTEXIND.NS
# APOLLOPIPE.NS
# ARVINDFASN.NS
# ARVIND.NS
# ASHOKA.NS
# ASTEC.NS
# ASTRAMICRO.NS
# ASTRAZEN.NS
# AUTOAXLES.NS
# AVALON.NS
# BASF.NS
# BAJAJCON.NS
# BAJAJHIND.NS
# BALMLAWRIE.NS
# BARBEQUE.NS
# BEPL.NS
# BOMDYEING.NS
# CARERATING.NS
# CMSINFO.NS
# CAMLINFINE.NS
# CAPLIPOINT.NS
# CARTRADE.NS
# CARYSIL.NS
# CHENNPETRO.NS
# CHOICEIN.NS
# CIGNITITEC.NS
# CONFIPET.NS
# COSMOFIRST.NS
# DBREALTY.NS
# DBCORP.NS
# DCBBANK.NS
# DCXINDIA.NS
# DALMIASUG.NS
# DATAMATICS.NS
# DEN.NS
# DHANI.NS
# DBL.NS
# DISHTV.NS
# DCAL.NS
# DIVGIITTS.NS
# DODLA.NS
# DOLLAR.NS
# DREAMFOLKS.NS
# DWARKESH.NS
# ESABINDIA.NS
# EDELWEISS.NS
# ELECON.NS
# EMIL.NS
# ELECTCAST.NS
# ETHOSLTD.NS
# EVEREADY.NS
# FIEMIND.NS
# FCL.NS
# FINOPB.NS
# FUSION.NS
# GET&D.NS
# GHCL.NS
# GABRIEL.NS
# GANESHHOUC.NS
# GRSE.NS
# GARFIBRES.NS
# GATEWAY.NS
# GLOBUSSPR.NS
# ...
