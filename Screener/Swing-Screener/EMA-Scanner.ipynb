# %% [markdown]
# # EMA Scanner

# %%
from tabulate import tabulate
import yfinance as yf
import pandas as pd
import pandas_ta as ta
import datetime

# Define the tickers and time rangenifty50_symbols
tickers = ["HDFCBANK.NS", "TATASTEEL.NS", "WIPRO.NS", "ICICIBANK.NS", "RELIANCE.NS"]


start_time = datetime.time(9, 30)  # 09:30 AM
end_time = datetime.time(15, 0)  # 03:00 PM

def fetch_and_calculate_ema(ticker):
    # Fetching 5min interval data for the current day, suppress progress bar
    data = yf.download(ticker, interval='5m', period='1mo', progress=False)
    
    # Calculating 10 and 20 EMA
    
    data['EMA10'] = ta.ema(data['Close'], length=25)
    data['EMA20'] = ta.ema(data['Close'], length=44)
    
    return data

def check_crossover(data, ticker):
    crossover_events = pd.DataFrame()
    for i in range(1, len(data)):
        current_time = data.index[i].time()
        if start_time <= current_time <= end_time:
            # Check for positive crossover
            if (data['EMA10'].iloc[i] > data['EMA20'].iloc[i]) and (data['EMA10'].iloc[i-1] < data['EMA20'].iloc[i-1]):
                event = pd.DataFrame([{
                    "DateTime": data.index[i],
                    "Ticker": ticker,
                    "Crossover Type": "Positive EMA Crossover",
                    "Close": data['Close'].iloc[i],
                    "EMA10": data['EMA10'].iloc[i],
                    "EMA20": data['EMA20'].iloc[i]
                }])
                crossover_events = pd.concat([crossover_events, event])
            
            # Check for negative crossover
            elif (data['EMA10'].iloc[i] < data['EMA20'].iloc[i]) and (data['EMA10'].iloc[i-1] > data['EMA20'].iloc[i-1]):
                event = pd.DataFrame([{
                    "DateTime": data.index[i],
                    "Ticker": ticker,
                    "Crossover Type": "Negative EMA Crossover",
                    "Close": data['Close'].iloc[i],
                    "EMA10": data['EMA10'].iloc[i],
                    "EMA20": data['EMA20'].iloc[i]
                }])
                crossover_events = pd.concat([crossover_events, event])
                
    return crossover_events



# ANSI color codes
RED = '\033[31m'
GREEN = '\033[32m'
RESET = '\033[0m'


def scan_tickers():
    all_crossovers = pd.DataFrame()
    for ticker in tickers:
        data = fetch_and_calculate_ema(ticker)
        crossover_events = check_crossover(data, ticker)
        all_crossovers = pd.concat([all_crossovers, crossover_events])
    
    if not all_crossovers.empty:
        # Convert 'DateTime' to a datetime object if it's not already
        all_crossovers['DateTime'] = pd.to_datetime(all_crossovers['DateTime'])
        
        # Round off the values to two decimal places
        all_crossovers['Close'] = all_crossovers['Close'].round(2)
        all_crossovers['EMA10'] = all_crossovers['EMA10'].round(2)
        all_crossovers['EMA20'] = all_crossovers['EMA20'].round(2)
        
        # Sort by DateTime
        all_crossovers.sort_values(by='DateTime', inplace=True)

        # Apply color coding to the 'Crossover Type'
        all_crossovers['Crossover Type'] = all_crossovers['Crossover Type'].apply(
            lambda x: f"{GREEN}{x}{RESET}" if "Positive" in x else f"{RED}{x}{RESET}"
        )

        # Tabulate and print
        tabulated_data = tabulate(all_crossovers, headers='keys', tablefmt='fancy_grid', showindex=False)
        print(tabulated_data)
        return True

# Run the scan
scan_tickers()
# Out:
# ╒═══════════════════════════╤══════════════╤════════════════════════╤═════════╤═════════╤═════════╕
# │ DateTime                  │ Ticker       │ Crossover Type         │   Close │   EMA10 │   EMA20 │
# ╞═══════════════════════════╪══════════════╪════════════════════════╪═════════╪═════════╪═════════╡
# │ 2024-01-03 12:55:00+05:30 │ WIPRO.NS     │ Negative EMA Crossover │  458.05 │  458.73 │  458.74 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-04 10:05:00+05:30 │ HDFCBANK.NS  │ Positive EMA Crossover │ 1685.35 │ 1677.61 │ 1677.4  │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-04 10:55:00+05:30 │ RELIANCE.NS  │ Positive EMA Crossover │ 2602.6  │ 2599.92 │ 2599.89 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-04 11:10:00+05:30 │ RELIANCE.NS  │ Negative EMA Crossover │ 2597.45 │ 2599.8  │ 2599.83 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-04 12:30:00+05:30 │ RELIANCE.NS  │ Positive EMA Crossover │ 2607    │ 2599.81 │ 2599.61 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-04 14:05:00+05:30 │ RELIANCE.NS  │ Negative EMA Crossover │ 2597    │ 2600.66 │ 2600.73 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-05 09:30:00+05:30 │ WIPRO.NS     │ Positive EMA Crossover │  459.4  │  454.65 │  454.63 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-05 09:35:00+05:30 │ RELIANCE.NS  │ Positive EMA Crossover │ 2601.25 │ 2598.83 │ 2598.83 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-05 10:00:00+05:30 │ TATASTEEL.NS │ Positive EMA Crossover │  135.6  │  134.49 │  134.47 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-05 10:20:00+05:30 │ HDFCBANK.NS  │ Negative EMA Crossover │ 1683.7  │ 1684.63 │ 1684.65 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-05 11:50:00+05:30 │ TATASTEEL.NS │ Negative EMA Crossover │  134.25 │  134.61 │  134.62 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-05 13:50:00+05:30 │ RELIANCE.NS  │ Negative EMA Crossover │ 2601.3  │ 2605.38 │ 2605.41 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-05 13:50:00+05:30 │ WIPRO.NS     │ Negative EMA Crossover │  456.1  │  457.88 │  457.89 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-05 14:15:00+05:30 │ ICICIBANK.NS │ Negative EMA Crossover │  986.15 │  991.32 │  991.42 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-05 14:55:00+05:30 │ HDFCBANK.NS  │ Positive EMA Crossover │ 1683.8  │ 1675.41 │ 1675.38 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-08 09:30:00+05:30 │ TATASTEEL.NS │ Positive EMA Crossover │  135.1  │  134.21 │  134.19 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-08 10:00:00+05:30 │ TATASTEEL.NS │ Negative EMA Crossover │  134    │  134.17 │  134.18 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-08 11:25:00+05:30 │ HDFCBANK.NS  │ Negative EMA Crossover │ 1675.45 │ 1677.11 │ 1677.14 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-08 11:40:00+05:30 │ RELIANCE.NS  │ Negative EMA Crossover │ 2604.4  │ 2610.13 │ 2610.27 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-08 12:10:00+05:30 │ ICICIBANK.NS │ Negative EMA Crossover │  990.75 │  993.06 │  993.13 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-09 10:10:00+05:30 │ RELIANCE.NS  │ Positive EMA Crossover │ 2594.5  │ 2592.48 │ 2592.43 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-09 10:20:00+05:30 │ TATASTEEL.NS │ Positive EMA Crossover │  133.7  │  132.86 │  132.85 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-09 10:30:00+05:30 │ ICICIBANK.NS │ Positive EMA Crossover │  993.1  │  988.53 │  988.47 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-09 10:45:00+05:30 │ HDFCBANK.NS  │ Positive EMA Crossover │ 1673.1  │ 1668.38 │ 1668.33 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-09 13:25:00+05:30 │ WIPRO.NS     │ Negative EMA Crossover │  455    │  455.58 │  455.59 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-09 13:45:00+05:30 │ HDFCBANK.NS  │ Negative EMA Crossover │ 1668.2  │ 1670.97 │ 1671.03 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-09 14:20:00+05:30 │ ICICIBANK.NS │ Negative EMA Crossover │  982.95 │  990.9  │  991.12 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-09 14:25:00+05:30 │ RELIANCE.NS  │ Negative EMA Crossover │ 2586.6  │ 2597.59 │ 2597.64 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-09 14:55:00+05:30 │ TATASTEEL.NS │ Negative EMA Crossover │  133.75 │  133.91 │  133.91 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-10 11:00:00+05:30 │ ICICIBANK.NS │ Positive EMA Crossover │  989    │  986.77 │  986.7  │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-10 12:00:00+05:30 │ TATASTEEL.NS │ Positive EMA Crossover │  133.7  │  133.46 │  133.45 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-10 12:05:00+05:30 │ RELIANCE.NS  │ Positive EMA Crossover │ 2594    │ 2590.66 │ 2590.64 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-10 12:20:00+05:30 │ RELIANCE.NS  │ Negative EMA Crossover │ 2588.35 │ 2590.62 │ 2590.63 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-10 12:35:00+05:30 │ RELIANCE.NS  │ Positive EMA Crossover │ 2592.8  │ 2590.71 │ 2590.67 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-10 12:40:00+05:30 │ RELIANCE.NS  │ Negative EMA Crossover │ 2588.35 │ 2590.53 │ 2590.57 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-10 13:30:00+05:30 │ RELIANCE.NS  │ Positive EMA Crossover │ 2591.05 │ 2590.59 │ 2590.58 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-10 13:35:00+05:30 │ HDFCBANK.NS  │ Positive EMA Crossover │ 1656.25 │ 1654.72 │ 1654.72 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-10 15:00:00+05:30 │ WIPRO.NS     │ Positive EMA Crossover │  453.3  │  451.35 │  451.32 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-11 09:50:00+05:30 │ HDFCBANK.NS  │ Negative EMA Crossover │ 1652.3  │ 1655.64 │ 1655.71 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-11 11:05:00+05:30 │ ICICIBANK.NS │ Negative EMA Crossover │  989.05 │  991.22 │  991.27 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-11 12:00:00+05:30 │ HDFCBANK.NS  │ Positive EMA Crossover │ 1657.2  │ 1654.66 │ 1654.63 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-11 12:05:00+05:30 │ WIPRO.NS     │ Negative EMA Crossover │  452.1  │  452.35 │  452.35 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-11 13:20:00+05:30 │ ICICIBANK.NS │ Positive EMA Crossover │  991.5  │  990.73 │  990.72 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-11 13:50:00+05:30 │ HDFCBANK.NS  │ Negative EMA Crossover │ 1652.9  │ 1655.28 │ 1655.34 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-15 09:40:00+05:30 │ TATASTEEL.NS │ Negative EMA Crossover │  135.4  │  135.64 │  135.65 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-16 13:05:00+05:30 │ RELIANCE.NS  │ Negative EMA Crossover │ 2772.6  │ 2779.21 │ 2779.32 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-16 13:15:00+05:30 │ ICICIBANK.NS │ Negative EMA Crossover │ 1007.55 │ 1011.35 │ 1011.37 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-16 13:35:00+05:30 │ TATASTEEL.NS │ Negative EMA Crossover │  134.35 │  135.15 │  135.17 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-16 13:55:00+05:30 │ TATASTEEL.NS │ Positive EMA Crossover │  136.65 │  135.25 │  135.22 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-17 09:45:00+05:30 │ TATASTEEL.NS │ Negative EMA Crossover │  135.1  │  136.03 │  136.04 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-17 11:20:00+05:30 │ WIPRO.NS     │ Positive EMA Crossover │  488.65 │  484.63 │  484.59 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-17 12:20:00+05:30 │ WIPRO.NS     │ Negative EMA Crossover │  483.1  │  484.71 │  484.75 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-18 10:55:00+05:30 │ ICICIBANK.NS │ Positive EMA Crossover │  988.45 │  984.27 │  984.23 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-18 11:50:00+05:30 │ WIPRO.NS     │ Positive EMA Crossover │  487.95 │  479.63 │  479.43 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-18 13:15:00+05:30 │ ICICIBANK.NS │ Negative EMA Crossover │  982.25 │  985.74 │  985.84 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-18 13:30:00+05:30 │ RELIANCE.NS  │ Positive EMA Crossover │ 2728.8  │ 2719.39 │ 2719.33 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-19 11:10:00+05:30 │ RELIANCE.NS  │ Negative EMA Crossover │ 2724.75 │ 2728.55 │ 2728.55 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-19 13:30:00+05:30 │ RELIANCE.NS  │ Positive EMA Crossover │ 2736.1  │ 2726.79 │ 2726.77 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-19 14:25:00+05:30 │ WIPRO.NS     │ Negative EMA Crossover │  484.45 │  485.76 │  485.78 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-19 14:45:00+05:30 │ ICICIBANK.NS │ Negative EMA Crossover │  999.75 │ 1002.76 │ 1002.78 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-23 09:45:00+05:30 │ RELIANCE.NS  │ Negative EMA Crossover │ 2727.35 │ 2731.27 │ 2731.32 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-23 10:30:00+05:30 │ TATASTEEL.NS │ Negative EMA Crossover │  133.25 │  134    │  134    │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-23 14:25:00+05:30 │ ICICIBANK.NS │ Negative EMA Crossover │ 1025.55 │ 1029.42 │ 1029.44 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-24 09:50:00+05:30 │ ICICIBANK.NS │ Positive EMA Crossover │ 1031.55 │ 1028.69 │ 1028.66 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-24 10:10:00+05:30 │ ICICIBANK.NS │ Negative EMA Crossover │ 1027.95 │ 1028.6  │ 1028.61 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-24 10:15:00+05:30 │ ICICIBANK.NS │ Positive EMA Crossover │ 1030.5  │ 1028.75 │ 1028.7  │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-24 10:20:00+05:30 │ HDFCBANK.NS  │ Positive EMA Crossover │ 1446.75 │ 1435.57 │ 1435.57 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-24 10:40:00+05:30 │ TATASTEEL.NS │ Positive EMA Crossover │  132.25 │  131.58 │  131.56 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-24 10:55:00+05:30 │ ICICIBANK.NS │ Negative EMA Crossover │ 1026.3  │ 1028.74 │ 1028.77 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-24 12:10:00+05:30 │ RELIANCE.NS  │ Positive EMA Crossover │ 2663.95 │ 2661.57 │ 2661.51 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-24 12:35:00+05:30 │ RELIANCE.NS  │ Negative EMA Crossover │ 2660.35 │ 2661.38 │ 2661.42 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-24 12:45:00+05:30 │ RELIANCE.NS  │ Positive EMA Crossover │ 2662.5  │ 2661.47 │ 2661.46 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-24 14:05:00+05:30 │ WIPRO.NS     │ Positive EMA Crossover │  474.25 │  471.97 │  471.91 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-25 10:10:00+05:30 │ HDFCBANK.NS  │ Negative EMA Crossover │ 1439    │ 1445.78 │ 1446.01 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-25 11:20:00+05:30 │ WIPRO.NS     │ Negative EMA Crossover │  473.85 │  474.93 │  474.96 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-25 13:00:00+05:30 │ TATASTEEL.NS │ Negative EMA Crossover │  133.95 │  134.48 │  134.5  │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-25 13:10:00+05:30 │ ICICIBANK.NS │ Positive EMA Crossover │ 1002    │  997.79 │  997.73 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-29 09:35:00+05:30 │ WIPRO.NS     │ Positive EMA Crossover │  474.35 │  471.7  │  471.63 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-29 09:40:00+05:30 │ TATASTEEL.NS │ Positive EMA Crossover │  134.4  │  133.78 │  133.78 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-29 14:10:00+05:30 │ ICICIBANK.NS │ Negative EMA Crossover │ 1017.45 │ 1019.22 │ 1019.23 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-29 14:20:00+05:30 │ WIPRO.NS     │ Negative EMA Crossover │  473.2  │  473.83 │  473.83 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-30 09:55:00+05:30 │ HDFCBANK.NS  │ Negative EMA Crossover │ 1449    │ 1452.85 │ 1452.97 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-30 11:20:00+05:30 │ RELIANCE.NS  │ Negative EMA Crossover │ 2846.2  │ 2861.23 │ 2861.58 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-30 11:50:00+05:30 │ RELIANCE.NS  │ Positive EMA Crossover │ 2862.3  │ 2861.89 │ 2861.87 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-30 12:05:00+05:30 │ RELIANCE.NS  │ Negative EMA Crossover │ 2857.9  │ 2861.59 │ 2861.71 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-30 13:00:00+05:30 │ ICICIBANK.NS │ Positive EMA Crossover │ 1015.35 │ 1014.92 │ 1014.91 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-30 14:25:00+05:30 │ WIPRO.NS     │ Negative EMA Crossover │  475.8  │  479.2  │  479.24 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-30 14:25:00+05:30 │ TATASTEEL.NS │ Negative EMA Crossover │  135.45 │  136.11 │  136.13 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-30 14:35:00+05:30 │ ICICIBANK.NS │ Negative EMA Crossover │ 1012.35 │ 1015.31 │ 1015.31 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-30 14:50:00+05:30 │ ICICIBANK.NS │ Positive EMA Crossover │ 1016.3  │ 1015.32 │ 1015.31 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-31 09:40:00+05:30 │ HDFCBANK.NS  │ Positive EMA Crossover │ 1454.25 │ 1445.62 │ 1445.44 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-31 10:05:00+05:30 │ ICICIBANK.NS │ Positive EMA Crossover │ 1029.95 │ 1015.96 │ 1015.53 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-31 10:55:00+05:30 │ TATASTEEL.NS │ Positive EMA Crossover │  136.35 │  135.81 │  135.8  │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-31 11:15:00+05:30 │ RELIANCE.NS  │ Positive EMA Crossover │ 2850    │ 2845.2  │ 2845.12 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-31 12:45:00+05:30 │ TATASTEEL.NS │ Negative EMA Crossover │  135.5  │  135.88 │  135.88 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-31 13:05:00+05:30 │ WIPRO.NS     │ Positive EMA Crossover │  475.15 │  473.81 │  473.79 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-31 13:10:00+05:30 │ RELIANCE.NS  │ Negative EMA Crossover │ 2842.95 │ 2848.81 │ 2848.84 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-31 14:15:00+05:30 │ ICICIBANK.NS │ Negative EMA Crossover │ 1023.1  │ 1027.59 │ 1027.67 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-02-01 10:30:00+05:30 │ WIPRO.NS     │ Negative EMA Crossover │  474.5  │  475.15 │  475.17 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-02-01 10:45:00+05:30 │ HDFCBANK.NS  │ Positive EMA Crossover │ 1470.3  │ 1465.63 │ 1465.52 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-02-01 11:00:00+05:30 │ ICICIBANK.NS │ Positive EMA Crossover │ 1031    │ 1026.04 │ 1025.88 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-02-01 12:40:00+05:30 │ HDFCBANK.NS  │ Negative EMA Crossover │ 1465.3  │ 1466.06 │ 1466.08 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-02-01 12:45:00+05:30 │ HDFCBANK.NS  │ Positive EMA Crossover │ 1469    │ 1466.28 │ 1466.21 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-02-01 13:10:00+05:30 │ HDFCBANK.NS  │ Negative EMA Crossover │ 1464.5  │ 1466.15 │ 1466.16 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-02-01 13:15:00+05:30 │ TATASTEEL.NS │ Negative EMA Crossover │  135.6  │  135.92 │  135.92 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-02-01 13:15:00+05:30 │ RELIANCE.NS  │ Negative EMA Crossover │ 2847.95 │ 2857.48 │ 2857.72 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-02-01 13:30:00+05:30 │ ICICIBANK.NS │ Negative EMA Crossover │ 1023.1  │ 1026.7  │ 1026.8  │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-02-01 14:50:00+05:30 │ RELIANCE.NS  │ Positive EMA Crossover │ 2859.95 │ 2855.19 │ 2855.16 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-02-02 09:45:00+05:30 │ TATASTEEL.NS │ Positive EMA Crossover │  136.6  │  135.66 │  135.63 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-02-02 12:30:00+05:30 │ HDFCBANK.NS  │ Negative EMA Crossover │ 1460.75 │ 1468.98 │ 1469.1  │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-02-02 13:25:00+05:30 │ ICICIBANK.NS │ Negative EMA Crossover │ 1033.5  │ 1038.4  │ 1038.51 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-02-02 13:35:00+05:30 │ RELIANCE.NS  │ Negative EMA Crossover │ 2899.45 │ 2904.17 │ 2904.23 │
# ├───────────────────────────┼──────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-02-02 15:00:00+05:30 │ RELIANCE.NS  │ Positive EMA Crossover │ 2912.35 │ 2903.04 │ 2902.86 │
# ╘═══════════════════════════╧══════════════╧════════════════════════╧═════════╧═════════╧═════════╛
# True

# %%
from tabulate import tabulate
import yfinance as yf
import pandas as pd
import pandas_ta as ta
import datetime

# Define the tickers and time range
tickers = ['AAVAS.NS', 'AEGISCHEM.NS', 'AFFLE.NS', 'ARE&M.NS', 'AMBER.NS', 'ANGELONE.NS', 'ANURAS.NS', 'APARINDS.NS', 'BLS.NS', 'BSE.NS', 'BALAMINES.NS', 'BALRAMCHIN.NS', 'BIKAJI.NS', 'BIRLACORPN.NS', 'BSOFT.NS', 'CESC.NS', 'CIEINDIA.NS', 'CAMPUS.NS', 'CANFINHOME.NS', 'CEATLTD.NS', 'CENTRALBK.NS', 'CDSL.NS', 'CENTURYTEX.NS', 'CHAMBLFERT.NS', 'CUB.NS', 'COCHINSHIP.NS', 'CAMS.NS', 'CREDITACC.NS', 'CYIENT.NS', 'DATAPATTNS.NS', 'DEEPAKFERT.NS', 'EASEMYTRIP.NS', 'ELGIEQUIP.NS', 'EQUITASBNK.NS', 'EXIDEIND.NS', 'FINCABLES.NS', 'FSL.NS', 'GLENMARK.NS', 'MEDANTA.NS', 'GRANULES.NS', 'GRAPHITE.NS', 'GNFC.NS', 'HFCL.NS', 'HAPPSTMNDS.NS', 'HINDCOPPER.NS', 'HUDCO.NS', 'IDBI.NS', 'IDFC.NS', 'IIFL.NS', 'IRB.NS', 'INDIAMART.NS', 'IEX.NS', 'IOB.NS', 'INTELLECT.NS', 'JBCHEPHARM.NS', 'JBMA.NS', 'JKLAKSHMI.NS', 'JUBLINGREA.NS', 'JYOTHYLAB.NS', 'KEI.NS', 'KRBL.NS', 'KALYANKJIL.NS', 'KARURVYSYA.NS', 'KEC.NS', 'LATENTVIEW.NS', 'LXCHEM.NS', 'MGL.NS', 'MANAPPURAM.NS', 'MRPL.NS', 'MEDPLUS.NS', 'METROPOLIS.NS', 'MCX.NS', 'NATCOPHARM.NS', 'NBCC.NS', 'NLCINDIA.NS', 'NSLNISP.NS', 'NATIONALUM.NS', 'PNBHOUSING.NS', 'PVRINOX.NS', 'PPLPHARMA.NS', 'PRAJIND.NS', 'RBLBANK.NS', 'RITES.NS', 'RADICO.NS', 'RAYMOND.NS', 'REDINGTON.NS', 'ROUTE.NS', 'SJVN.NS', 'RENUKA.NS', 'SONATSOFTW.NS', 'SUZLON.NS', 'TANLA.NS', 'TTML.NS', 'TEJASNET.NS', 'TRITURBINE.NS', 'UCOBANK.NS', 'UTIAMC.NS', 'VIPIND.NS', 'WELSPUNLIV.NS', 'ZENSARTECH.NS']

start_time = datetime.time(9, 30)  # 09:30 AM
end_time = datetime.time(15, 0)  # 03:00 PM

def fetch_and_calculate_ema(ticker):
    # Fetching 1d interval data for the last 1 month, suppress progress bar
    data = yf.download(ticker, interval='1h', period='1mo', progress=False)
    
    # Calculating 25 and 44 EMA
    data['EMA10'] = ta.ema(data['Close'], length=25)
    data['EMA20'] = ta.ema(data['Close'], length=44)
    
    return data

def check_crossover(data, ticker):
    crossover_events = pd.DataFrame()
    for i in range(1, len(data)):
        current_time = data.index[i].time()
        if start_time <= current_time <= end_time:
            # Check for positive crossover
            if (data['EMA10'].iloc[i] > data['EMA20'].iloc[i]) and (data['EMA10'].iloc[i-1] <= data['EMA20'].iloc[i-1]):
                event = pd.DataFrame([{
                    "DateTime": data.index[i],
                    "Ticker": ticker,
                    "Crossover Type": "Positive EMA Crossover",
                    "Close": data['Close'].iloc[i],
                    "EMA10": data['EMA10'].iloc[i],
                    "EMA20": data['EMA20'].iloc[i]
                }])
                crossover_events = pd.concat([crossover_events, event])
            
            # Check for negative crossover
            elif (data['EMA10'].iloc[i] < data['EMA20'].iloc[i]) and (data['EMA10'].iloc[i-1] >= data['EMA20'].iloc[i-1]):
                event = pd.DataFrame([{
                    "DateTime": data.index[i],
                    "Ticker": ticker,
                    "Crossover Type": "Negative EMA Crossover",
                    "Close": data['Close'].iloc[i],
                    "EMA10": data['EMA10'].iloc[i],
                    "EMA20": data['EMA20'].iloc[i]
                }])
                crossover_events = pd.concat([crossover_events, event])
                
    return crossover_events

def scan_tickers():
    all_crossovers = pd.DataFrame()
    for ticker in tickers:
        data = fetch_and_calculate_ema(ticker)
        crossover_events = check_crossover(data, ticker)
        all_crossovers = pd.concat([all_crossovers, crossover_events])
    
    if not all_crossovers.empty:
        # Convert 'DateTime' to a datetime object if it's not already
        all_crossovers['DateTime'] = pd.to_datetime(all_crossovers['DateTime'])
        
        # Round off the values to two decimal places
        all_crossovers['Close'] = all_crossovers['Close'].round(2)
        all_crossovers['EMA10'] = all_crossovers['EMA10'].round(2)
        all_crossovers['EMA20'] = all_crossovers['EMA20'].round(2)
        
        # Sort by DateTime
        all_crossovers.sort_values(by='DateTime', inplace=True)

        # Apply color coding to the 'Crossover Type'
        all_crossovers['Crossover Type'] = all_crossovers['Crossover Type'].apply(
            lambda x: f"{GREEN}{x}{RESET}" if "Positive" in x else f"{RED}{x}{RESET}"
        )

        # Tabulate and print
        tabulated_data = tabulate(all_crossovers, headers='keys', tablefmt='fancy_grid', showindex=False)
        print(tabulated_data)
        return True

# Run the scan
scan_tickers()
# Out:
# ╒═══════════════════════════╤═══════════════╤════════════════════════╤═════════╤═════════╤═════════╕
# │ DateTime                  │ Ticker        │ Crossover Type         │   Close │   EMA10 │   EMA20 │
# ╞═══════════════════════════╪═══════════════╪════════════════════════╪═════════╪═════════╪═════════╡
# │ 2024-01-11 13:15:00+05:30 │ NLCINDIA.NS   │ Positive EMA Crossover │  233.1  │  227.81 │  227.75 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-11 13:15:00+05:30 │ IEX.NS        │ Positive EMA Crossover │  165.15 │  164.04 │  164.02 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-11 13:15:00+05:30 │ JYOTHYLAB.NS  │ Negative EMA Crossover │  498    │  503.23 │  503.33 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-11 14:15:00+05:30 │ FINCABLES.NS  │ Positive EMA Crossover │ 1046    │ 1037.83 │ 1037.6  │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-11 14:15:00+05:30 │ RBLBANK.NS    │ Positive EMA Crossover │  295.15 │  286.64 │  286.43 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-12 10:15:00+05:30 │ JYOTHYLAB.NS  │ Positive EMA Crossover │  508.85 │  503.63 │  503.53 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-12 11:15:00+05:30 │ KARURVYSYA.NS │ Positive EMA Crossover │  168.55 │  166.67 │  166.61 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-12 12:15:00+05:30 │ MGL.NS        │ Positive EMA Crossover │ 1261.9  │ 1225.54 │ 1225.24 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-12 12:15:00+05:30 │ HAPPSTMNDS.NS │ Positive EMA Crossover │  920.05 │  901.68 │  901.46 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-12 14:15:00+05:30 │ BIRLACORPN.NS │ Negative EMA Crossover │ 1427.65 │ 1433.34 │ 1433.42 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-15 11:15:00+05:30 │ CYIENT.NS     │ Positive EMA Crossover │ 2331.2  │ 2256.77 │ 2254.54 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-15 11:15:00+05:30 │ INTELLECT.NS  │ Positive EMA Crossover │  830.5  │  819.97 │  819.8  │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-15 11:15:00+05:30 │ IOB.NS        │ Positive EMA Crossover │   44.55 │   43.74 │   43.74 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-15 12:15:00+05:30 │ UCOBANK.NS    │ Positive EMA Crossover │   41.75 │   41.06 │   41.05 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-15 12:15:00+05:30 │ GRANULES.NS   │ Positive EMA Crossover │  427.9  │  413.15 │  412.95 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-15 12:15:00+05:30 │ SJVN.NS       │ Positive EMA Crossover │   97.95 │   94.27 │   94.24 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-15 12:15:00+05:30 │ IDBI.NS       │ Positive EMA Crossover │   69.35 │   68.21 │   68.2  │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-15 12:15:00+05:30 │ CHAMBLFERT.NS │ Positive EMA Crossover │  385.75 │  381.53 │  381.39 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-15 13:15:00+05:30 │ JYOTHYLAB.NS  │ Negative EMA Crossover │  500.5  │  503.52 │  503.58 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-15 13:15:00+05:30 │ CENTRALBK.NS  │ Positive EMA Crossover │   52.75 │   51.58 │   51.55 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-15 14:15:00+05:30 │ GLENMARK.NS   │ Positive EMA Crossover │  911.2  │  888.3  │  887.65 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-15 14:15:00+05:30 │ PNBHOUSING.NS │ Positive EMA Crossover │  797.75 │  791.49 │  791.46 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-15 14:15:00+05:30 │ IEX.NS        │ Negative EMA Crossover │  163.25 │  164.27 │  164.27 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-16 11:15:00+05:30 │ TTML.NS       │ Negative EMA Crossover │   92.4  │   93.53 │   93.55 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-16 11:15:00+05:30 │ ZENSARTECH.NS │ Negative EMA Crossover │  574.5  │  575.53 │  575.53 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-16 12:15:00+05:30 │ ANGELONE.NS   │ Negative EMA Crossover │ 3386    │ 3693.47 │ 3703.34 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-16 14:15:00+05:30 │ ELGIEQUIP.NS  │ Positive EMA Crossover │  543.45 │  537.18 │  537.04 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-16 14:15:00+05:30 │ AFFLE.NS      │ Negative EMA Crossover │ 1293.35 │ 1300.38 │ 1300.42 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-17 10:15:00+05:30 │ AFFLE.NS      │ Positive EMA Crossover │ 1306.25 │ 1300.63 │ 1300.53 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-17 11:15:00+05:30 │ GLENMARK.NS   │ Negative EMA Crossover │  874.5  │  888.13 │  888.16 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-17 11:15:00+05:30 │ REDINGTON.NS  │ Negative EMA Crossover │  175.95 │  178.56 │  178.56 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-17 11:15:00+05:30 │ KALYANKJIL.NS │ Negative EMA Crossover │  361.55 │  375.33 │  375.71 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-17 11:15:00+05:30 │ AAVAS.NS      │ Negative EMA Crossover │ 1538.45 │ 1576.82 │ 1577.89 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-17 11:15:00+05:30 │ AFFLE.NS      │ Negative EMA Crossover │ 1297    │ 1300.35 │ 1300.38 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-17 12:15:00+05:30 │ JYOTHYLAB.NS  │ Positive EMA Crossover │  509.25 │  503.22 │  503.18 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-17 12:15:00+05:30 │ BIRLACORPN.NS │ Negative EMA Crossover │ 1412.75 │ 1435.47 │ 1435.88 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-17 13:15:00+05:30 │ CENTURYTEX.NS │ Negative EMA Crossover │ 1403.05 │ 1446.92 │ 1448.08 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-17 13:15:00+05:30 │ KRBL.NS       │ Negative EMA Crossover │  371.65 │  376.19 │  376.26 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-17 13:15:00+05:30 │ WELSPUNLIV.NS │ Negative EMA Crossover │  148.25 │  151.75 │  151.84 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-17 13:15:00+05:30 │ EQUITASBNK.NS │ Negative EMA Crossover │  110.55 │  112.88 │  112.94 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-17 14:15:00+05:30 │ CREDITACC.NS  │ Negative EMA Crossover │ 1657.6  │ 1688.4  │ 1689.27 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-18 10:15:00+05:30 │ NBCC.NS       │ Negative EMA Crossover │   87.25 │   89.63 │   89.66 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-18 10:15:00+05:30 │ CENTRALBK.NS  │ Negative EMA Crossover │   50.85 │   51.83 │   51.83 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-18 11:15:00+05:30 │ CHAMBLFERT.NS │ Negative EMA Crossover │  378.6  │  382.5  │  382.55 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-18 11:15:00+05:30 │ CYIENT.NS     │ Negative EMA Crossover │ 2223    │ 2259.71 │ 2260.49 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-18 12:15:00+05:30 │ CENTRALBK.NS  │ Positive EMA Crossover │   52.8  │   51.9  │   51.87 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-18 13:15:00+05:30 │ IDFC.NS       │ Negative EMA Crossover │  123.4  │  124.92 │  124.95 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-18 13:15:00+05:30 │ CEATLTD.NS    │ Positive EMA Crossover │ 2531.8  │ 2470.43 │ 2468.77 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-18 13:15:00+05:30 │ HAPPSTMNDS.NS │ Negative EMA Crossover │  882.95 │  916.93 │  917.35 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-18 14:15:00+05:30 │ IOB.NS        │ Positive EMA Crossover │   44.15 │   43.95 │   43.95 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-18 14:15:00+05:30 │ CANFINHOME.NS │ Positive EMA Crossover │  778.25 │  768.23 │  768.15 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-18 14:15:00+05:30 │ GRAPHITE.NS   │ Negative EMA Crossover │  541.85 │  551.95 │  552.26 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-18 14:15:00+05:30 │ UCOBANK.NS    │ Positive EMA Crossover │   41.35 │   41.23 │   41.23 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-19 10:15:00+05:30 │ DATAPATTNS.NS │ Negative EMA Crossover │ 1931    │ 1948.24 │ 1948.34 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-19 11:15:00+05:30 │ NBCC.NS       │ Positive EMA Crossover │   94.9  │   89.87 │   89.74 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-19 14:15:00+05:30 │ PPLPHARMA.NS  │ Positive EMA Crossover │  143.9  │  140.86 │  140.8  │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-19 14:15:00+05:30 │ EASEMYTRIP.NS │ Negative EMA Crossover │   46.35 │   46.71 │   46.71 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-19 14:15:00+05:30 │ MANAPPURAM.NS │ Positive EMA Crossover │  178.4  │  174.09 │  174.02 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-23 10:15:00+05:30 │ HFCL.NS       │ Positive EMA Crossover │   98.9  │   87.75 │   87.56 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-23 10:15:00+05:30 │ NSLNISP.NS    │ Positive EMA Crossover │   53.65 │   49.56 │   49.55 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-23 10:15:00+05:30 │ CAMS.NS       │ Negative EMA Crossover │ 2766    │ 2799.74 │ 2800.61 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-23 10:15:00+05:30 │ EQUITASBNK.NS │ Negative EMA Crossover │  111.6  │  112.5  │  112.51 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-23 11:15:00+05:30 │ SUZLON.NS     │ Negative EMA Crossover │   40.45 │   42.32 │   42.34 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-23 12:15:00+05:30 │ CESC.NS       │ Negative EMA Crossover │  132.65 │  139.27 │  139.39 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-23 12:15:00+05:30 │ MCX.NS        │ Negative EMA Crossover │ 3051.2  │ 3144.92 │ 3147.48 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-23 12:15:00+05:30 │ MANAPPURAM.NS │ Negative EMA Crossover │  171.35 │  173.95 │  173.97 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-23 12:15:00+05:30 │ CIEINDIA.NS   │ Negative EMA Crossover │  484.4  │  488.28 │  488.38 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-23 12:15:00+05:30 │ CANFINHOME.NS │ Negative EMA Crossover │  741.05 │  768.83 │  769.36 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-23 13:15:00+05:30 │ FSL.NS        │ Negative EMA Crossover │  193.75 │  199.7  │  199.84 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-23 13:15:00+05:30 │ LATENTVIEW.NS │ Negative EMA Crossover │  455.5  │  464.18 │  464.39 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-23 14:15:00+05:30 │ IIFL.NS       │ Negative EMA Crossover │  625    │  644.96 │  645.49 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-23 14:15:00+05:30 │ TANLA.NS      │ Negative EMA Crossover │ 1136.1  │ 1163.77 │ 1164.58 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-24 11:15:00+05:30 │ METROPOLIS.NS │ Positive EMA Crossover │ 1594.9  │ 1581.38 │ 1581.33 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-24 11:15:00+05:30 │ RAYMOND.NS    │ Negative EMA Crossover │ 1754.6  │ 1785.51 │ 1785.99 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-24 12:15:00+05:30 │ JBCHEPHARM.NS │ Positive EMA Crossover │ 1698.65 │ 1655.99 │ 1654.72 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-24 12:15:00+05:30 │ HINDCOPPER.NS │ Positive EMA Crossover │  269.3  │  264.06 │  263.99 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-24 12:15:00+05:30 │ KEI.NS        │ Positive EMA Crossover │ 3244.8  │ 3116.62 │ 3113.98 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-24 13:15:00+05:30 │ NATIONALUM.NS │ Positive EMA Crossover │  135.7  │  132.98 │  132.94 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-24 13:15:00+05:30 │ JKLAKSHMI.NS  │ Positive EMA Crossover │  886.9  │  871.27 │  871.1  │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-25 10:15:00+05:30 │ GLENMARK.NS   │ Positive EMA Crossover │  898    │  881.12 │  880.55 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-25 11:15:00+05:30 │ APARINDS.NS   │ Positive EMA Crossover │ 5508.15 │ 5468.92 │ 5468.16 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-25 12:15:00+05:30 │ MANAPPURAM.NS │ Positive EMA Crossover │  175.7  │  173.65 │  173.61 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-25 14:15:00+05:30 │ MCX.NS        │ Positive EMA Crossover │ 3215.8  │ 3131.84 │ 3130.67 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-25 14:15:00+05:30 │ EASEMYTRIP.NS │ Positive EMA Crossover │   47.25 │   46.47 │   46.45 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-25 14:15:00+05:30 │ ZENSARTECH.NS │ Positive EMA Crossover │  575.9  │  565.17 │  565.01 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-29 10:15:00+05:30 │ METROPOLIS.NS │ Negative EMA Crossover │ 1564.1  │ 1583.51 │ 1583.82 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-29 10:15:00+05:30 │ JBMA.NS       │ Positive EMA Crossover │ 1927.75 │ 1865.58 │ 1863.56 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-29 11:15:00+05:30 │ PNBHOUSING.NS │ Negative EMA Crossover │  813.05 │  839.36 │  839.83 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-29 12:15:00+05:30 │ SUZLON.NS     │ Positive EMA Crossover │   43.1  │   42    │   41.99 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-29 12:15:00+05:30 │ BIKAJI.NS     │ Positive EMA Crossover │  583.2  │  575.94 │  575.84 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-29 12:15:00+05:30 │ TTML.NS       │ Positive EMA Crossover │   91    │   90.56 │   90.55 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-29 14:15:00+05:30 │ BALRAMCHIN.NS │ Positive EMA Crossover │  391.45 │  386.96 │  386.82 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-29 14:15:00+05:30 │ BIRLACORPN.NS │ Positive EMA Crossover │ 1473    │ 1418.64 │ 1417.65 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-30 10:15:00+05:30 │ LATENTVIEW.NS │ Positive EMA Crossover │  475    │  460.12 │  459.9  │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-30 11:15:00+05:30 │ RADICO.NS     │ Positive EMA Crossover │ 1646.1  │ 1637.19 │ 1637.13 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-30 12:15:00+05:30 │ REDINGTON.NS  │ Positive EMA Crossover │  181    │  177.16 │  177.07 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-30 12:15:00+05:30 │ RADICO.NS     │ Negative EMA Crossover │ 1629.8  │ 1636.62 │ 1636.81 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-30 12:15:00+05:30 │ WELSPUNLIV.NS │ Positive EMA Crossover │  150.55 │  146    │  145.88 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-30 12:15:00+05:30 │ FSL.NS        │ Positive EMA Crossover │  205    │  198.11 │  197.92 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-30 14:15:00+05:30 │ PPLPHARMA.NS  │ Negative EMA Crossover │  138.75 │  141.99 │  142.07 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-31 10:15:00+05:30 │ CENTURYTEX.NS │ Positive EMA Crossover │ 1409.35 │ 1394.79 │ 1394.43 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-31 10:15:00+05:30 │ EASEMYTRIP.NS │ Negative EMA Crossover │   46.35 │   46.47 │   46.47 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-31 10:15:00+05:30 │ KALYANKJIL.NS │ Positive EMA Crossover │  377.2  │  362.43 │  362    │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-31 11:15:00+05:30 │ KEI.NS        │ Positive EMA Crossover │ 3178.95 │ 3144.39 │ 3144.2  │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-31 11:15:00+05:30 │ SONATSOFTW.NS │ Positive EMA Crossover │  758.9  │  746.76 │  746.74 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-31 11:15:00+05:30 │ PPLPHARMA.NS  │ Positive EMA Crossover │  143.8  │  142.22 │  142.19 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-31 12:15:00+05:30 │ EXIDEIND.NS   │ Positive EMA Crossover │  329.9  │  319.39 │  319.05 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-31 12:15:00+05:30 │ BSE.NS        │ Positive EMA Crossover │ 2276.45 │ 2182.95 │ 2182.28 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-31 12:15:00+05:30 │ EASEMYTRIP.NS │ Positive EMA Crossover │   46.65 │   46.49 │   46.49 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-31 13:15:00+05:30 │ CUB.NS        │ Positive EMA Crossover │  145.3  │  143.61 │  143.58 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-31 13:15:00+05:30 │ IEX.NS        │ Positive EMA Crossover │  147.1  │  143.56 │  143.54 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-31 14:15:00+05:30 │ TTML.NS       │ Positive EMA Crossover │   92.65 │   90.42 │   90.4  │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-31 14:15:00+05:30 │ KALYANKJIL.NS │ Negative EMA Crossover │  349.55 │  361.14 │  361.35 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-01-31 14:15:00+05:30 │ GRAPHITE.NS   │ Positive EMA Crossover │  545.5  │  537.42 │  537.38 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-02-01 11:15:00+05:30 │ PPLPHARMA.NS  │ Negative EMA Crossover │  140.05 │  142.14 │  142.17 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-02-01 11:15:00+05:30 │ JYOTHYLAB.NS  │ Negative EMA Crossover │  515.15 │  529.36 │  529.78 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-02-01 14:15:00+05:30 │ CEATLTD.NS    │ Negative EMA Crossover │ 2611.75 │ 2679.1  │ 2680.64 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-02-01 14:15:00+05:30 │ RAYMOND.NS    │ Positive EMA Crossover │ 1781    │ 1760.47 │ 1760.2  │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-02-02 10:15:00+05:30 │ CIEINDIA.NS   │ Positive EMA Crossover │  489.4  │  484.27 │  484.13 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-02-02 12:15:00+05:30 │ ZENSARTECH.NS │ Negative EMA Crossover │  562.35 │  567.96 │  568.15 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-02-02 13:15:00+05:30 │ RBLBANK.NS    │ Positive EMA Crossover │  268.4  │  262.72 │  262.65 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-02-02 13:15:00+05:30 │ GRANULES.NS   │ Positive EMA Crossover │  421.15 │  415.05 │  414.88 │
# ├───────────────────────────┼───────────────┼────────────────────────┼─────────┼─────────┼─────────┤
# │ 2024-02-02 14:15:00+05:30 │ FINCABLES.NS  │ Negative EMA Crossover │ 1069.95 │ 1086.47 │ 1086.71 │
# ╘═══════════════════════════╧═══════════════╧════════════════════════╧═════════╧═════════╧═════════╛
# True
